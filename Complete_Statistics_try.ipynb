# %%
 import json
import zipfile
import os
import sys
import io
from ast import literal_eval
import pandas as pd
from itertools import chain
from itertools import groupby
import unicodedata
import numpy as np
import collections

from string import punctuation
translator = str.maketrans('','',punctuation)

# %%
class repository: 
    def __init__(self, policy, title, chapter, section, article):
        self.policy = policy
        self.title = title
        self.chapter = chapter
        self.section = section
        self.article = article
        
        
    def __repr__(self): #how to print the repository to the console
        return 'policy:' + self.policy + ' title:' + self.title + ' chapter:' + self.chapter + ' section:' + self.section + ' article:' + self.article          
   
    @classmethod
    def from_repository_name(cls, rep_str):                #2nd initializer that creates a repository object directly from a repository string e.g 'EU_32008R1099_Title_0_Chapter_0_Section_0_Article_03.txt'
        folder_parts = rep_str.split('_')                  #split the string at '_' into parts 
        policy = folder_parts[0] + '_' + folder_parts[1]   #we only want to split at every 2nd '_', so merge the 1. and 2., 3. and 4. again 
        if folder_parts[2] in  ['front', 'Whereas']:       #exeption for the 'whereas' and 'front'
            title = 'front'
            chapter = 'None'
            section = 'None'
            article = 'None'
        else:
            title = folder_parts[2] + '_' + folder_parts[3]
            chapter = folder_parts[4] + '_' + folder_parts[5]
            section = folder_parts[6] + '_' + folder_parts[7]
            article = folder_parts[8] + '_' + folder_parts[9]
        
        return cls(policy,title, chapter, section, article)  #return a repository with the previously defined attributes
    
    def match(self, other):            #checks if the search-criteria defined in repository 'other' is matching the the current repository                                                
        self_value_set = set([x for x in list(self.__dict__.values()) if x != 'None']) #creates a set of all the attributes ignoring 'None'    
        other_value_set = set([x for x in list(other.__dict__.values()) if x != 'None'])
        

        return set(other_value_set).issubset(self_value_set) #returns True if the attributes of the search-criteria is a subset of the attributes of the current directory (=match)
    
class token:
    def __init__(self, start, stop, text, rep, tag_count = 0):
        self.start = start
        self.stop = stop
        self.text = text
        self.rep = rep
        self.tag_count = tag_count
        
    def __repr__(self):
        return 'start:' + str(self.start) + ' stop:' + str(self.stop) + ' text:' + self.text + ' tag_count:' + str(self.tag_count)
        
    
class tag:
    def __init__(self, layer_, type_, tag_, start, stop, text, tokens, rep):
        self.layer_ = layer_
        self.type_ = type_
        self.tag_ = tag_
        self.start = start
        self.stop = stop
        self.text = text
        self.tokens = tokens
        self.rep = rep
        
        
    def __eq__(self, other): 
        if not isinstance(other, tag):
            # don't attempt to compare against unrelated types
            return NotImplemented

        return self.layer_ == other.layer_ and self.type_ == other.type_ and self.tag_ == other.tag_ and self.start == other.start and self.stop == other.stop
    
    def __repr__(self): #for debugging purpose, defines how object is printed
        return "layer:" + self.layer_ + " type:" + self.type_ + " tag:" + self.tag_ + " start:" + str(self.start) + " stop:" + str(self.stop) + " text:" + self.text + '\n'

    def get_start(self):
        return self.start
    
class Evaluator:
    
    def __init__(self, df):
        self.df = df
        
        
    def _get_iterator_all(self): #returns a iterator of all the tags present in the dataframe
        
        return chain.from_iterable(self.df['Tags'])
        
        
    def _get_iterator_conditional_rep(self, conditional_rep, column): #returns a list for all the tags that match the attributes defined in the 'conditional_rep' 
  
        iterator = chain.from_iterable(self.df[column])
        return [x for x in iterator if type(x)!= str and x.rep.match(conditional_rep) == True]
        
        
    def get_tag_list(self, conditional_rep, item, value):
       
        iterator = self._get_iterator_conditional_rep(conditional_rep, 'Tags')
        
        if item == 'None' and value == 'None':
            return [x for x in iterator if type(x)!= str ]
        if item == 'layer':
            return [x for x in iterator if type(x)!= str and x.layer_ == value]
        if item == 'type':
            return [x for x in iterator if type(x)!= str and x.type_ == value]
        if item == 'tag':
            return [x for x in iterator if type(x)!= str and x.tag_ == value]
        
    def get_tag_frequency(self, conditional_rep, item, value):
        return len(self.get_tag_list(conditional_rep, item, value))    

    def get_span_distro(self, conditional_rep, item, value, return_format, level = 'character'):
        
        tag_list = self.get_tag_list(conditional_rep, item, value)
        
        if level == 'character':
            len_list = [(x.stop - x.start) for x in tag_list]
        if level == 'token':
            len_list = [len(x.tokens) for x in tag_list]
            
        len_dict = collections.Counter(len_list)
        
        if return_format == 'dict':
            return dict(sorted(len_dict.items(), key=lambda item: item[1], reverse=True))
            
        
        if return_format == 'list':
            distro_list = []
            for i in range(1,max(len_list)+1):
                distro_list.append(len_list.count(i))
            return distro_list
                      
     
    def get_tag_count(self, conditional_rep, item, value):
        return len(self.get_tag_list(conditional_rep, item, value))
    
    def get_token_list_from_repository(self, conditional_rep):
        token_iterator = self._get_iterator_conditional_rep(conditional_rep, 'Tokens')
        return list(token_iterator)
    
    def get_token_count_from_repository(self, conditional_rep):
        return len(self.get_token_list_from_repository(conditional_rep))
        
       
    
    
    def get_tokens_from_tag_list(self, conditional_rep, item, value):
        tag_list = self.get_tag_list(conditional_rep, item, value)
        return list(chain.from_iterable([x.tokens for x in tag_list]))
    
    
    def get_token_count_from_tag_list(self, conditional_rep, item, value):
        return len(self.get_tokens_from_tag_list(conditional_rep, item, value)) 
    
    
    def most_frequent_labeled_tokens(self, conditional_rep, item, value):
        tag_list = self.get_tag_list(conditional_rep, item, value) #get the taglist of all the tag that match search criteria
        token_iterator = chain.from_iterable([x.tokens for x in tag_list]) #retrieve all the tokens from the tag list and create a iterator (since the list contains sublists)
        token_counter_dict = collections.Counter([x.text for x in token_iterator]) #get a list the text of the token, count the different elements and create a dict
        return dict(sorted(token_counter_dict.items(), key=lambda item: item[1], reverse=True))  #sort the dict by counts
    
    
    def get_label_count_per_token_distro(self, conditional_rep, return_format):
        token_iterator = self._get_iterator_conditional_rep(conditional_rep, 'Tokens')
        token_counter_dict = collections.Counter([x.tag_count for x in token_iterator]) #get a list the text of the token, count the different elements and create a dict
        label_counter_list = [x.tag_count for x in token_iterator]
        
        if return_format == 'dict':
            return dict(sorted(token_counter_dict.items(), key=lambda item: item[1], reverse=True))
        
        if return_format == 'list':
            distro_list = []
            for i in range(0,max(label_counter_list)+1):
                distro_list.append(label_counter_list.count(i))
            return distro_list

# %%
stat_df = pd.DataFrame(columns = ['Policy', 'Text','Tags', 'Tokens']) #create the initial dataframe
tagsets = ['Policydesigncharacteristics','Technologyandapplicationspecificity','Instrumenttypes']

# %%
from definitions import ROOT_DIR


data_path = os.path.join(ROOT_DIR,'data')

annotator_path = os.path.join(data_path , 'annotator_data/annotation')  
path = os.path.join(data_path , 'annotator_data/curation')

subdirs = [o for o in os.listdir(path) if os.path.isdir(path)] #identify all the subdirs which correspond to different articles
os.chdir(path)

# %%
for subdir in subdirs:
   
    try:
        archive = zipfile.ZipFile(os.path.join(subdir, str(os.listdir(subdir)[0])), 'r') #decode compressed json in zip file
        json_file_byte = archive.read('CURATION_USER.json')      #this is a binary
        
        json_file_byte_decode = json_file_byte.decode('utf8')    #decode to json
    
        data = json.loads(json_file_byte_decode)
    
    except:
        stat_df = stat_df.append(pd.Series([subdir, 'error', 'error', 'error'], index=stat_df.columns ), ignore_index=True) #append error column if cannot read data

        
    else:
        taglist = []      #create epty list holding all the tags of the aragraph (= article)
        rep = repository.from_repository_name(subdir[0:-4])  #directory name in string format
        sentence = data['_referenced_fss']['1']['sofaString'].lower()  #raw text of the paragraph (all in lower case)
        all_tokens_json = data['_views']['_InitialView']['Token']
        all_tokens_json[0]['begin'] = 0                            #the first token is missing the beginning
        token_list = [token(x['begin'], x['end'], sentence[x['begin']:x['end']], rep) for x in all_tokens_json]
        sentence_normalized = normalize_and_replace_text(sentence) 
        
        for category in data['_views']['_InitialView']:  #loop trough the custom layers
  
            if category in tagsets:
                    
                for annotation in data['_views']['_InitialView'][category]: #loop trough all the tags
                    
                    type_ = list(annotation.keys())[-1]     #this part handles empty annotations. The last entry of the dict usually contains the type and the tag.
                                                            #for empty tags, the last entry is a integer
                    if type(type_) != str:                  
                        type_ = ''
                    
                    tag_ = list(annotation.values())[-1]
                    if type(tag_) != str:
                        tag_ = ''
                        
                    start = annotation['begin']
                    stop = annotation['end']
                    tag_tokens = [x for x in token_list if  x.start >= start and x.stop <= stop]
                    
                    for tag_token in tag_tokens:
                        tag_token.tag_count +=1
                    
                    taglist.append(tag(category, type_, tag_ , start ,stop , sentence[start:stop], tag_tokens, rep))
                    
        stat_df = stat_df.append(pd.Series([subdir[0:-4], sentence ,taglist, token_list], index=stat_df.columns ), ignore_index=True)     
stat_df['tokens cleaned'] = stat_df['Text'].apply(clean_text)

# %%
new_index = np.arange(0, len(stat_df)-1)
stat_df.reindex(new_index)

stat_df.head()
# Out:
#                                               Policy  \
# 0  EU_32006L0032_Title_0_Chapter_1_Section_0_Arti...
# 1  EU_32009L0028_Title_0_Chapter_0_Section_0_Arti...
# 2  EU_32019L0944_Title_0_Chapter_6_Section_3_Arti...
# 3  EU_32019R0631_Title_0_Chapter_0_Section_0_Arti...
# 4  EU_32018R1999_Title_0_Chapter_2_Section_0_Arti...
#
#                                                 Text  \
# 0  article 3\r\ndefinitions\r\nfor the purposes o...
# 1  article 7\r\njoint projects between member sta...
# 2  article 47\r\nindependence of the transmission...
# 3  article 14\r\nadjustment of m0 and tm0 values\...
# 4  article 3\r\nintegrated national energy and cl...
#
#                                                 Tags  \
# 0  [layer:Instrumenttypes type:InstrumentType tag...
# 1  [layer:Policydesigncharacteristics type:Actor ...
# 2  [layer:Instrumenttypes type:InstrumentType tag...
# 3  [layer:Instrumenttypes type:InstrumentType tag...
# 4  [layer:Instrumenttypes type:InstrumentType tag...
#
#                                               Tokens  \
# 0  [start:0 stop:7 text:article tag_count:0, star...
# 1  [start:0 stop:7 text:article tag_count:0, star...
# 2  [start:0 stop:7 text:article tag_count:0, star...
# 3  [start:0 stop:7 text:article tag_count:0, star...
# 4  [start:0 stop:7 text:article tag_count:0, star...
#
#                                       tokens cleaned
# 0  [article, #, definitions, for, the, purposes, ...
# 1  [article, #, joint, projects, between, member,...
# 2  [article, #, independence, of, the, transmissi...
# 3  [article, #, adjustment, of, m0, and, tm0, val...
# 4  [article, #, integrated, national, energy, and...

# %%
stat_df['Policy'][0]
# Out:
# 'EU_32009L0028_Title_0_Chapter_0_Section_0_Article_07'

# %%
hello = stat_df['Tags'][0]
hello
# Out:
# [class:Policydesigncharacteristics type:Actor tag:Addressee_default start:34 stop:47 text:Member States,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_default start:66 stop:79 text:Member States,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_sector start:247 stop:264 text:private operators,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_monitored start:272 stop:285 text:Member States,
#  class:Policydesigncharacteristics type:Actor tag:Authority_monitoring start:303 stop:313 text:Commission,
#  class:Policydesigncharacteristics type:Resource tag:Resource_Other start:345 stop:658 text:electricity, heating or cooling from renewable energy sources produced by any joint project in their territory, that became operational after 25 June 2009, or by the increased capacity of an installation that was refurbished after that date, which is to be regarded as counting towards the national overall target,
#  class:Policydesigncharacteristics type:Objective tag:Objective_QualIntention start:635 stop:658 text:national overall target,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:670 stop:682 text:Member State,
#  class:Policydesigncharacteristics type:Compliance tag:Form_monitoring start:703 stop:723 text:measuring compliance,
#  class:Policydesigncharacteristics type:Compliance tag:Form_monitoring start:828 stop:903 text:describe the proposed installation or identify the refurbished installation,
#  class:Policydesigncharacteristics type:Compliance tag:Form_monitoring start:911 stop:1107 text:specify the proportion or amount of electricity or heating or cooling produced from the installation which is to be regarded as counting towards the national overall target of another Member State,
#  class:Policydesigncharacteristics type:Compliance tag:Form_monitoring start:911 stop:1011 text:specify the proportion or amount of electricity or heating or cooling produced from the installation,
#  class:Policydesigncharacteristics type:Resource tag:Resource_Other start:947 stop:1083 text:electricity or heating or cooling produced from the installation which is to be regarded as counting towards the national overall target,
#  class:Policydesigncharacteristics type:Objective tag:Objective_QualIntention start:1060 stop:1083 text:national overall target,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:1095 stop:1107 text:Member State,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:1128 stop:1140 text:Member State,
#  class:Policydesigncharacteristics type:Resource tag:Resource_Other start:1261 stop:1353 text:electricity or heating or cooling produced by the installation from renewable energy sources,
#  class:Policydesigncharacteristics type:Objective tag:Objective_QualIntention start:1396 stop:1419 text:national overall target,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:1433 stop:1445 text:Member State,
#  class:Policydesigncharacteristics type:Time tag:Time_PolDuration start:1501 stop:1523 text:not extend beyond 2020,
#  class:Policydesigncharacteristics type:Time tag:Time_PolDuration start:1543 stop:1579 text:joint project may extend beyond 2020,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_default start:1694 stop:1706 text:Member State,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:1739 stop:1751 text:Member State,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:141 stop:216 text:production of electricity, heating or cooling from renewable energy sources,
#  class:Technologyandapplicationspecificity type:ApplicationSpecificity tag:App_LowCarbon start:155 stop:216 text:electricity, heating or cooling from renewable energy sources,
#  class:Technologyandapplicationspecificity type:EnergySpecificity tag:Energy_LowCarbon start:192 stop:216 text:renewable energy sources,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:345 stop:436 text:electricity, heating or cooling from renewable energy sources produced by any joint project,
#  class:Technologyandapplicationspecificity type:ApplicationSpecificity tag:App_LowCarbon start:345 stop:406 text:electricity, heating or cooling from renewable energy sources,
#  class:Technologyandapplicationspecificity type:EnergySpecificity tag:Energy_LowCarbon start:382 stop:406 text:renewable energy sources,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:536 stop:548 text:installation,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:850 stop:862 text:installation,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:891 stop:903 text:installation,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:947 stop:1011 text:electricity or heating or cooling produced from the installation,
#  class:Technologyandapplicationspecificity type:ApplicationSpecificity tag:App_LowCarbon start:947 stop:980 text:electricity or heating or cooling,
#  class:Technologyandapplicationspecificity type:ApplicationSpecificity tag:App_LowCarbon start:1261 stop:1353 text:electricity or heating or cooling produced by the installation from renewable energy sources,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:1295 stop:1353 text:produced by the installation from renewable energy sources,
#  class:Technologyandapplicationspecificity type:EnergySpecificity tag:Energy_LowCarbon start:1329 stop:1353 text:renewable energy sources]

# %%
test_eval = Evaluator(stat_df)
test_dir = repository('EU_32009L0028', 'None', 'Chapter_0', 'None', 'Article_07')
test_eval.get_tag_list(test_dir, 'None', 'None')
# Out:
# [class:Policydesigncharacteristics type:Actor tag:Addressee_default start:34 stop:47 text:Member States,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_default start:66 stop:79 text:Member States,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_sector start:247 stop:264 text:private operators,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_monitored start:272 stop:285 text:Member States,
#  class:Policydesigncharacteristics type:Actor tag:Authority_monitoring start:303 stop:313 text:Commission,
#  class:Policydesigncharacteristics type:Resource tag:Resource_Other start:345 stop:658 text:electricity, heating or cooling from renewable energy sources produced by any joint project in their territory, that became operational after 25 June 2009, or by the increased capacity of an installation that was refurbished after that date, which is to be regarded as counting towards the national overall target,
#  class:Policydesigncharacteristics type:Objective tag:Objective_QualIntention start:635 stop:658 text:national overall target,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:670 stop:682 text:Member State,
#  class:Policydesigncharacteristics type:Compliance tag:Form_monitoring start:703 stop:723 text:measuring compliance,
#  class:Policydesigncharacteristics type:Compliance tag:Form_monitoring start:828 stop:903 text:describe the proposed installation or identify the refurbished installation,
#  class:Policydesigncharacteristics type:Compliance tag:Form_monitoring start:911 stop:1107 text:specify the proportion or amount of electricity or heating or cooling produced from the installation which is to be regarded as counting towards the national overall target of another Member State,
#  class:Policydesigncharacteristics type:Compliance tag:Form_monitoring start:911 stop:1011 text:specify the proportion or amount of electricity or heating or cooling produced from the installation,
#  class:Policydesigncharacteristics type:Resource tag:Resource_Other start:947 stop:1083 text:electricity or heating or cooling produced from the installation which is to be regarded as counting towards the national overall target,
#  class:Policydesigncharacteristics type:Objective tag:Objective_QualIntention start:1060 stop:1083 text:national overall target,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:1095 stop:1107 text:Member State,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:1128 stop:1140 text:Member State,
#  class:Policydesigncharacteristics type:Resource tag:Resource_Other start:1261 stop:1353 text:electricity or heating or cooling produced by the installation from renewable energy sources,
#  class:Policydesigncharacteristics type:Objective tag:Objective_QualIntention start:1396 stop:1419 text:national overall target,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:1433 stop:1445 text:Member State,
#  class:Policydesigncharacteristics type:Time tag:Time_PolDuration start:1501 stop:1523 text:not extend beyond 2020,
#  class:Policydesigncharacteristics type:Time tag:Time_PolDuration start:1543 stop:1579 text:joint project may extend beyond 2020,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_default start:1694 stop:1706 text:Member State,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:1739 stop:1751 text:Member State,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:141 stop:216 text:production of electricity, heating or cooling from renewable energy sources,
#  class:Technologyandapplicationspecificity type:ApplicationSpecificity tag:App_LowCarbon start:155 stop:216 text:electricity, heating or cooling from renewable energy sources,
#  class:Technologyandapplicationspecificity type:EnergySpecificity tag:Energy_LowCarbon start:192 stop:216 text:renewable energy sources,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:345 stop:436 text:electricity, heating or cooling from renewable energy sources produced by any joint project,
#  class:Technologyandapplicationspecificity type:ApplicationSpecificity tag:App_LowCarbon start:345 stop:406 text:electricity, heating or cooling from renewable energy sources,
#  class:Technologyandapplicationspecificity type:EnergySpecificity tag:Energy_LowCarbon start:382 stop:406 text:renewable energy sources,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:536 stop:548 text:installation,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:850 stop:862 text:installation,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:891 stop:903 text:installation,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:947 stop:1011 text:electricity or heating or cooling produced from the installation,
#  class:Technologyandapplicationspecificity type:ApplicationSpecificity tag:App_LowCarbon start:947 stop:980 text:electricity or heating or cooling,
#  class:Technologyandapplicationspecificity type:ApplicationSpecificity tag:App_LowCarbon start:1261 stop:1353 text:electricity or heating or cooling produced by the installation from renewable energy sources,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:1295 stop:1353 text:produced by the installation from renewable energy sources,
#  class:Technologyandapplicationspecificity type:EnergySpecificity tag:Energy_LowCarbon start:1329 stop:1353 text:renewable energy sources]

# %%
[x.tag_count for x in stat_df['Tokens'][0] if x.tag_count == 5 ]
# Out:
# [5, 5, 5, 5, 5]

# %%
test_eval.get_tag_list(test_dir, 'None', 'None')
# Out:
# [class:Policydesigncharacteristics type:Actor tag:Addressee_default start:34 stop:47 text:Member States,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_default start:66 stop:79 text:Member States,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_sector start:247 stop:264 text:private operators,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_monitored start:272 stop:285 text:Member States,
#  class:Policydesigncharacteristics type:Actor tag:Authority_monitoring start:303 stop:313 text:Commission,
#  class:Policydesigncharacteristics type:Resource tag:Resource_Other start:345 stop:658 text:electricity, heating or cooling from renewable energy sources produced by any joint project in their territory, that became operational after 25 June 2009, or by the increased capacity of an installation that was refurbished after that date, which is to be regarded as counting towards the national overall target,
#  class:Policydesigncharacteristics type:Objective tag:Objective_QualIntention start:635 stop:658 text:national overall target,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:670 stop:682 text:Member State,
#  class:Policydesigncharacteristics type:Compliance tag:Form_monitoring start:703 stop:723 text:measuring compliance,
#  class:Policydesigncharacteristics type:Compliance tag:Form_monitoring start:828 stop:903 text:describe the proposed installation or identify the refurbished installation,
#  class:Policydesigncharacteristics type:Compliance tag:Form_monitoring start:911 stop:1107 text:specify the proportion or amount of electricity or heating or cooling produced from the installation which is to be regarded as counting towards the national overall target of another Member State,
#  class:Policydesigncharacteristics type:Compliance tag:Form_monitoring start:911 stop:1011 text:specify the proportion or amount of electricity or heating or cooling produced from the installation,
#  class:Policydesigncharacteristics type:Resource tag:Resource_Other start:947 stop:1083 text:electricity or heating or cooling produced from the installation which is to be regarded as counting towards the national overall target,
#  class:Policydesigncharacteristics type:Objective tag:Objective_QualIntention start:1060 stop:1083 text:national overall target,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:1095 stop:1107 text:Member State,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:1128 stop:1140 text:Member State,
#  class:Policydesigncharacteristics type:Resource tag:Resource_Other start:1261 stop:1353 text:electricity or heating or cooling produced by the installation from renewable energy sources,
#  class:Policydesigncharacteristics type:Objective tag:Objective_QualIntention start:1396 stop:1419 text:national overall target,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:1433 stop:1445 text:Member State,
#  class:Policydesigncharacteristics type:Time tag:Time_PolDuration start:1501 stop:1523 text:not extend beyond 2020,
#  class:Policydesigncharacteristics type:Time tag:Time_PolDuration start:1543 stop:1579 text:joint project may extend beyond 2020,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_default start:1694 stop:1706 text:Member State,
#  class:Policydesigncharacteristics type:Actor tag:Addressee_resource start:1739 stop:1751 text:Member State,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:141 stop:216 text:production of electricity, heating or cooling from renewable energy sources,
#  class:Technologyandapplicationspecificity type:ApplicationSpecificity tag:App_LowCarbon start:155 stop:216 text:electricity, heating or cooling from renewable energy sources,
#  class:Technologyandapplicationspecificity type:EnergySpecificity tag:Energy_LowCarbon start:192 stop:216 text:renewable energy sources,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:345 stop:436 text:electricity, heating or cooling from renewable energy sources produced by any joint project,
#  class:Technologyandapplicationspecificity type:ApplicationSpecificity tag:App_LowCarbon start:345 stop:406 text:electricity, heating or cooling from renewable energy sources,
#  class:Technologyandapplicationspecificity type:EnergySpecificity tag:Energy_LowCarbon start:382 stop:406 text:renewable energy sources,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:536 stop:548 text:installation,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:850 stop:862 text:installation,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:891 stop:903 text:installation,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:947 stop:1011 text:electricity or heating or cooling produced from the installation,
#  class:Technologyandapplicationspecificity type:ApplicationSpecificity tag:App_LowCarbon start:947 stop:980 text:electricity or heating or cooling,
#  class:Technologyandapplicationspecificity type:ApplicationSpecificity tag:App_LowCarbon start:1261 stop:1353 text:electricity or heating or cooling produced by the installation from renewable energy sources,
#  class:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_LowCarbon start:1295 stop:1353 text:produced by the installation from renewable energy sources,
#  class:Technologyandapplicationspecificity type:EnergySpecificity tag:Energy_LowCarbon start:1329 stop:1353 text:renewable energy sources]

# %%
test_eval.get_tag_count(test_dir, 'None', 'None')
# Out:
# 37

# %%
test_eval.get_span_distro(test_dir, 'None', 'None', 'dict')
# Out:
# {12: 9,
#  13: 3,
#  23: 3,
#  24: 3,
#  75: 2,
#  92: 2,
#  61: 2,
#  17: 1,
#  10: 1,
#  313: 1,
#  20: 1,
#  196: 1,
#  100: 1,
#  136: 1,
#  22: 1,
#  36: 1,
#  91: 1,
#  64: 1,
#  33: 1,
#  58: 1}

# %%
test_eval.get_tokens_from_tag_list(test_dir, 'None', 'None')
# Out:
# [start:34 stop:40 text:Member tag_count:1,
#  start:41 stop:47 text:States tag_count:1,
#  start:66 stop:72 text:Member tag_count:1,
#  start:73 stop:79 text:States tag_count:1,
#  start:247 stop:254 text:private tag_count:1,
#  start:255 stop:264 text:operators tag_count:1,
#  start:272 stop:278 text:Member tag_count:1,
#  start:279 stop:285 text:States tag_count:1,
#  start:303 stop:313 text:Commission tag_count:1,
#  start:345 stop:356 text:electricity tag_count:3,
#  start:356 stop:357 text:, tag_count:3,
#  start:358 stop:365 text:heating tag_count:3,
#  start:366 stop:368 text:or tag_count:3,
#  start:369 stop:376 text:cooling tag_count:3,
#  start:377 stop:381 text:from tag_count:3,
#  start:382 stop:391 text:renewable tag_count:4,
#  start:392 stop:398 text:energy tag_count:4,
#  start:399 stop:406 text:sources tag_count:4,
#  start:407 stop:415 text:produced tag_count:2,
#  start:416 stop:418 text:by tag_count:2,
#  start:419 stop:422 text:any tag_count:2,
#  start:423 stop:428 text:joint tag_count:2,
#  start:429 stop:436 text:project tag_count:2,
#  start:437 stop:439 text:in tag_count:1,
#  start:440 stop:445 text:their tag_count:1,
#  start:446 stop:455 text:territory tag_count:1,
#  start:455 stop:456 text:, tag_count:1,
#  start:457 stop:461 text:that tag_count:1,
#  start:462 stop:468 text:became tag_count:1,
#  start:469 stop:480 text:operational tag_count:1,
#  start:481 stop:486 text:after tag_count:1,
#  start:487 stop:489 text:25 tag_count:1,
#  start:489 stop:490 text:  tag_count:1,
#  start:490 stop:494 text:June tag_count:1,
#  start:495 stop:499 text:2009 tag_count:1,
#  start:499 stop:500 text:, tag_count:1,
#  start:501 stop:503 text:or tag_count:1,
#  start:504 stop:506 text:by tag_count:1,
#  start:507 stop:510 text:the tag_count:1,
#  start:511 stop:520 text:increased tag_count:1,
#  start:521 stop:529 text:capacity tag_count:1,
#  start:530 stop:532 text:of tag_count:1,
#  start:533 stop:535 text:an tag_count:1,
#  start:536 stop:548 text:installation tag_count:2,
#  start:549 stop:553 text:that tag_count:1,
#  start:554 stop:557 text:was tag_count:1,
#  start:558 stop:569 text:refurbished tag_count:1,
#  start:570 stop:575 text:after tag_count:1,
#  start:576 stop:580 text:that tag_count:1,
#  start:581 stop:585 text:date tag_count:1,
#  start:585 stop:586 text:, tag_count:1,
#  start:587 stop:592 text:which tag_count:1,
#  start:593 stop:595 text:is tag_count:1,
#  start:596 stop:598 text:to tag_count:1,
#  start:599 stop:601 text:be tag_count:1,
#  start:602 stop:610 text:regarded tag_count:1,
#  start:611 stop:613 text:as tag_count:1,
#  start:614 stop:622 text:counting tag_count:1,
#  start:623 stop:630 text:towards tag_count:1,
#  start:631 stop:634 text:the tag_count:1,
#  start:635 stop:643 text:national tag_count:2,
#  start:644 stop:651 text:overall tag_count:2,
#  start:652 stop:658 text:target tag_count:2,
#  start:635 stop:643 text:national tag_count:2,
#  start:644 stop:651 text:overall tag_count:2,
#  start:652 stop:658 text:target tag_count:2,
#  start:670 stop:676 text:Member tag_count:1,
#  start:677 stop:682 text:State tag_count:1,
#  start:703 stop:712 text:measuring tag_count:1,
#  start:713 stop:723 text:compliance tag_count:1,
#  start:828 stop:836 text:describe tag_count:1,
#  start:837 stop:840 text:the tag_count:1,
#  start:841 stop:849 text:proposed tag_count:1,
#  start:850 stop:862 text:installation tag_count:2,
#  start:863 stop:865 text:or tag_count:1,
#  start:866 stop:874 text:identify tag_count:1,
#  start:875 stop:878 text:the tag_count:1,
#  start:879 stop:890 text:refurbished tag_count:1,
#  start:891 stop:903 text:installation tag_count:2,
#  start:911 stop:918 text:specify tag_count:2,
#  start:919 stop:922 text:the tag_count:2,
#  start:923 stop:933 text:proportion tag_count:2,
#  start:934 stop:936 text:or tag_count:2,
#  start:937 stop:943 text:amount tag_count:2,
#  start:944 stop:946 text:of tag_count:2,
#  start:947 stop:958 text:electricity tag_count:5,
#  start:959 stop:961 text:or tag_count:5,
#  start:962 stop:969 text:heating tag_count:5,
#  start:970 stop:972 text:or tag_count:5,
#  start:973 stop:980 text:cooling tag_count:5,
#  start:981 stop:989 text:produced tag_count:4,
#  start:990 stop:994 text:from tag_count:4,
#  start:995 stop:998 text:the tag_count:4,
#  start:999 stop:1011 text:installation tag_count:4,
#  start:1012 stop:1017 text:which tag_count:2,
#  start:1018 stop:1020 text:is tag_count:2,
#  start:1021 stop:1023 text:to tag_count:2,
#  start:1024 stop:1026 text:be tag_count:2,
#  start:1027 stop:1035 text:regarded tag_count:2,
#  start:1036 stop:1038 text:as tag_count:2,
#  start:1039 stop:1047 text:counting tag_count:2,
#  start:1048 stop:1055 text:towards tag_count:2,
#  start:1056 stop:1059 text:the tag_count:2,
#  start:1060 stop:1068 text:national tag_count:3,
#  start:1069 stop:1076 text:overall tag_count:3,
#  start:1077 stop:1083 text:target tag_count:3,
#  start:1084 stop:1086 text:of tag_count:1,
#  start:1087 stop:1094 text:another tag_count:1,
#  start:1095 stop:1101 text:Member tag_count:2,
#  start:1102 stop:1107 text:State tag_count:2,
#  start:911 stop:918 text:specify tag_count:2,
#  start:919 stop:922 text:the tag_count:2,
#  start:923 stop:933 text:proportion tag_count:2,
#  start:934 stop:936 text:or tag_count:2,
#  start:937 stop:943 text:amount tag_count:2,
#  start:944 stop:946 text:of tag_count:2,
#  start:947 stop:958 text:electricity tag_count:5,
#  start:959 stop:961 text:or tag_count:5,
#  start:962 stop:969 text:heating tag_count:5,
#  start:970 stop:972 text:or tag_count:5,
#  start:973 stop:980 text:cooling tag_count:5,
#  start:981 stop:989 text:produced tag_count:4,
#  start:990 stop:994 text:from tag_count:4,
#  start:995 stop:998 text:the tag_count:4,
#  start:999 stop:1011 text:installation tag_count:4,
#  start:947 stop:958 text:electricity tag_count:5,
#  start:959 stop:961 text:or tag_count:5,
#  start:962 stop:969 text:heating tag_count:5,
#  start:970 stop:972 text:or tag_count:5,
#  start:973 stop:980 text:cooling tag_count:5,
#  start:981 stop:989 text:produced tag_count:4,
#  start:990 stop:994 text:from tag_count:4,
#  start:995 stop:998 text:the tag_count:4,
#  start:999 stop:1011 text:installation tag_count:4,
#  start:1012 stop:1017 text:which tag_count:2,
#  start:1018 stop:1020 text:is tag_count:2,
#  start:1021 stop:1023 text:to tag_count:2,
#  start:1024 stop:1026 text:be tag_count:2,
#  start:1027 stop:1035 text:regarded tag_count:2,
#  start:1036 stop:1038 text:as tag_count:2,
#  start:1039 stop:1047 text:counting tag_count:2,
#  start:1048 stop:1055 text:towards tag_count:2,
#  start:1056 stop:1059 text:the tag_count:2,
#  start:1060 stop:1068 text:national tag_count:3,
#  start:1069 stop:1076 text:overall tag_count:3,
#  start:1077 stop:1083 text:target tag_count:3,
#  start:1060 stop:1068 text:national tag_count:3,
#  start:1069 stop:1076 text:overall tag_count:3,
#  start:1077 stop:1083 text:target tag_count:3,
#  start:1095 stop:1101 text:Member tag_count:2,
#  start:1102 stop:1107 text:State tag_count:2,
#  start:1128 stop:1134 text:Member tag_count:1,
#  start:1135 stop:1140 text:State tag_count:1,
#  start:1261 stop:1272 text:electricity tag_count:2,
#  start:1273 stop:1275 text:or tag_count:2,
#  start:1276 stop:1283 text:heating tag_count:2,
#  start:1284 stop:1286 text:or tag_count:2,
#  start:1287 stop:1294 text:cooling tag_count:2,
#  start:1295 stop:1303 text:produced tag_count:3,
#  start:1304 stop:1306 text:by tag_count:3,
#  start:1307 stop:1310 text:the tag_count:3,
#  start:1311 stop:1323 text:installation tag_count:3,
#  start:1324 stop:1328 text:from tag_count:3,
#  start:1329 stop:1338 text:renewable tag_count:4,
#  start:1339 stop:1345 text:energy tag_count:4,
#  start:1346 stop:1353 text:sources tag_count:4,
#  start:1396 stop:1404 text:national tag_count:1,
#  start:1405 stop:1412 text:overall tag_count:1,
#  start:1413 stop:1419 text:target tag_count:1,
#  start:1433 stop:1439 text:Member tag_count:1,
#  start:1440 stop:1445 text:State tag_count:1,
#  start:1501 stop:1504 text:not tag_count:1,
#  start:1505 stop:1511 text:extend tag_count:1,
#  start:1512 stop:1518 text:beyond tag_count:1,
#  start:1519 stop:1523 text:2020 tag_count:1,
#  start:1543 stop:1548 text:joint tag_count:1,
#  start:1549 stop:1556 text:project tag_count:1,
#  start:1557 stop:1560 text:may tag_count:1,
#  start:1561 stop:1567 text:extend tag_count:1,
#  start:1568 stop:1574 text:beyond tag_count:1,
#  start:1575 stop:1579 text:2020 tag_count:1,
#  start:1694 stop:1700 text:Member tag_count:1,
#  start:1701 stop:1706 text:State tag_count:1,
#  start:1739 stop:1745 text:Member tag_count:1,
#  start:1746 stop:1751 text:State tag_count:1,
#  start:141 stop:151 text:production tag_count:1,
#  start:152 stop:154 text:of tag_count:1,
#  start:155 stop:166 text:electricity tag_count:2,
#  start:166 stop:167 text:, tag_count:2,
#  start:168 stop:175 text:heating tag_count:2,
#  start:176 stop:178 text:or tag_count:2,
#  start:179 stop:186 text:cooling tag_count:2,
#  start:187 stop:191 text:from tag_count:2,
#  start:192 stop:201 text:renewable tag_count:3,
#  start:202 stop:208 text:energy tag_count:3,
#  start:209 stop:216 text:sources tag_count:3,
#  start:155 stop:166 text:electricity tag_count:2,
#  start:166 stop:167 text:, tag_count:2,
#  start:168 stop:175 text:heating tag_count:2,
#  start:176 stop:178 text:or tag_count:2,
#  start:179 stop:186 text:cooling tag_count:2,
#  start:187 stop:191 text:from tag_count:2,
#  start:192 stop:201 text:renewable tag_count:3,
#  start:202 stop:208 text:energy tag_count:3,
#  start:209 stop:216 text:sources tag_count:3,
#  start:192 stop:201 text:renewable tag_count:3,
#  start:202 stop:208 text:energy tag_count:3,
#  start:209 stop:216 text:sources tag_count:3,
#  start:345 stop:356 text:electricity tag_count:3,
#  start:356 stop:357 text:, tag_count:3,
#  start:358 stop:365 text:heating tag_count:3,
#  start:366 stop:368 text:or tag_count:3,
#  start:369 stop:376 text:cooling tag_count:3,
#  start:377 stop:381 text:from tag_count:3,
#  start:382 stop:391 text:renewable tag_count:4,
#  start:392 stop:398 text:energy tag_count:4,
#  start:399 stop:406 text:sources tag_count:4,
#  start:407 stop:415 text:produced tag_count:2,
#  start:416 stop:418 text:by tag_count:2,
#  start:419 stop:422 text:any tag_count:2,
#  start:423 stop:428 text:joint tag_count:2,
#  start:429 stop:436 text:project tag_count:2,
#  start:345 stop:356 text:electricity tag_count:3,
#  start:356 stop:357 text:, tag_count:3,
#  start:358 stop:365 text:heating tag_count:3,
#  start:366 stop:368 text:or tag_count:3,
#  start:369 stop:376 text:cooling tag_count:3,
#  start:377 stop:381 text:from tag_count:3,
#  start:382 stop:391 text:renewable tag_count:4,
#  start:392 stop:398 text:energy tag_count:4,
#  start:399 stop:406 text:sources tag_count:4,
#  start:382 stop:391 text:renewable tag_count:4,
#  start:392 stop:398 text:energy tag_count:4,
#  start:399 stop:406 text:sources tag_count:4,
#  start:536 stop:548 text:installation tag_count:2,
#  start:850 stop:862 text:installation tag_count:2,
#  start:891 stop:903 text:installation tag_count:2,
#  start:947 stop:958 text:electricity tag_count:5,
#  start:959 stop:961 text:or tag_count:5,
#  start:962 stop:969 text:heating tag_count:5,
#  start:970 stop:972 text:or tag_count:5,
#  start:973 stop:980 text:cooling tag_count:5,
#  start:981 stop:989 text:produced tag_count:4,
#  start:990 stop:994 text:from tag_count:4,
#  start:995 stop:998 text:the tag_count:4,
#  start:999 stop:1011 text:installation tag_count:4,
#  start:947 stop:958 text:electricity tag_count:5,
#  start:959 stop:961 text:or tag_count:5,
#  start:962 stop:969 text:heating tag_count:5,
#  start:970 stop:972 text:or tag_count:5,
#  start:973 stop:980 text:cooling tag_count:5,
#  start:1261 stop:1272 text:electricity tag_count:2,
#  start:1273 stop:1275 text:or tag_count:2,
#  start:1276 stop:1283 text:heating tag_count:2,
#  start:1284 stop:1286 text:or tag_count:2,
#  start:1287 stop:1294 text:cooling tag_count:2,
#  start:1295 stop:1303 text:produced tag_count:3,
#  start:1304 stop:1306 text:by tag_count:3,
#  start:1307 stop:1310 text:the tag_count:3,
#  start:1311 stop:1323 text:installation tag_count:3,
#  start:1324 stop:1328 text:from tag_count:3,
#  start:1329 stop:1338 text:renewable tag_count:4,
#  start:1339 stop:1345 text:energy tag_count:4,
#  start:1346 stop:1353 text:sources tag_count:4,
#  start:1295 stop:1303 text:produced tag_count:3,
#  start:1304 stop:1306 text:by tag_count:3,
#  start:1307 stop:1310 text:the tag_count:3,
#  start:1311 stop:1323 text:installation tag_count:3,
#  start:1324 stop:1328 text:from tag_count:3,
#  start:1329 stop:1338 text:renewable tag_count:4,
#  start:1339 stop:1345 text:energy tag_count:4,
#  start:1346 stop:1353 text:sources tag_count:4,
#  start:1329 stop:1338 text:renewable tag_count:4,
#  start:1339 stop:1345 text:energy tag_count:4,
#  start:1346 stop:1353 text:sources tag_count:4]

# %%
test_eval.get_token_count_from_tag_list(test_dir, 'None', 'None')
# Out:
# 275

# %%
test_eval.most_frequent_labeled_tokens(test_dir, 'None', 'None')
# Out:
# {'or': 23,
#  'the': 15,
#  'installation': 13,
#  'electricity': 12,
#  'heating': 12,
#  'cooling': 12,
#  'from': 12,
#  'renewable': 11,
#  'energy': 11,
#  'sources': 11,
#  'Member': 10,
#  'produced': 9,
#  ',': 8,
#  'State': 7,
#  'by': 6,
#  'national': 6,
#  'overall': 6,
#  'target': 6,
#  'of': 5,
#  'States': 3,
#  'joint': 3,
#  'project': 3,
#  'that': 3,
#  'which': 3,
#  'is': 3,
#  'to': 3,
#  'be': 3,
#  'regarded': 3,
#  'as': 3,
#  'counting': 3,
#  'towards': 3,
#  'any': 2,
#  'after': 2,
#  'refurbished': 2,
#  'specify': 2,
#  'proportion': 2,
#  'amount': 2,
#  'extend': 2,
#  'beyond': 2,
#  '2020': 2,
#  'private': 1,
#  'operators': 1,
#  'Commission': 1,
#  'in': 1,
#  'their': 1,
#  'territory': 1,
#  'became': 1,
#  'operational': 1,
#  '25': 1,
#  '\xa0': 1,
#  'June': 1,
#  '2009': 1,
#  'increased': 1,
#  'capacity': 1,
#  'an': 1,
#  'was': 1,
#  'date': 1,
#  'measuring': 1,
#  'compliance': 1,
#  'describe': 1,
#  'proposed': 1,
#  'identify': 1,
#  'another': 1,
#  'not': 1,
#  'may': 1,
#  'production': 1}

# %%
test_eval.get_label_count_per_token_distro(test_dir, 'dict')
# Out:
# {0: 174, 1: 81, 2: 39, 3: 17, 4: 10, 5: 5}

# %%
test_eval.get_label_count_per_token_distro1(test_dir, 'None', 'None','dict')
# Out:
# {1: 81, 2: 78, 3: 51, 4: 40, 5: 25}

# %%
import matplotlib.pyplot as plt
plt.plot(test_eval.get_span_distro(hello,'None', 'None', 'list'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-172-e2d55573db24> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(test_eval.get_span_distro(hello,'None', 'None', 'list'))
#       3 plt.show()
#
# <ipython-input-153-6cd26d1e7c17> in get_span_distro(self, conditional_rep, item, value, return_format)
#     105     def get_span_distro(self, conditional_rep, item, value, return_format):
#     106
# --> 107         tag_list = self.get_tag_list(conditional_rep, item, value)
#     108         len_list = [(x.stop - x.start) for x in tag_list]
#     109         len_dict = collections.Counter(len_list)
#
# <ipython-input-153-6cd26d1e7c17> in get_tag_list(self, conditional_rep, item, value)
#      91     def get_tag_list(self, conditional_rep, item, value):
#      92
# ---> 93         iterator = self._get_iterator_conditional_rep(conditional_rep, 'Tags')
#      94
#      95         if item == 'None' and value == 'None':
#
# <ipython-input-153-6cd26d1e7c17> in _get_iterator_conditional_rep(self, conditional_rep, column)
#      86
#      87         iterator = chain.from_iterable(self.df[column])
# ---> 88         return [x for x in iterator if type(x)!= str and x.rep.match(conditional_rep) == True]
#      89
#      90
#
# <ipython-input-153-6cd26d1e7c17> in <listcomp>(.0)
#      86
#      87         iterator = chain.from_iterable(self.df[column])
# ---> 88         return [x for x in iterator if type(x)!= str and x.rep.match(conditional_rep) == True]
#      89
#      90
#
# <ipython-input-153-6cd26d1e7c17> in match(self, other)
#      30     def match(self, other):            #checks if the search-criteria defined in repository 'other' is matching the the current repository
#      31         self_value_set = set([x for x in list(self.__dict__.values()) if x != 'None']) #creates a set of all the attributes ignoring 'None'
# ---> 32         other_value_set = set([x for x in list(other.__dict__.values()) if x != 'None'])
#      33
#      34
#
# AttributeError: 'list' object has no attribute '__dict__'

# %%
test_eval.get_span_distro(hello,'class', 'Instrumenttypes', 'list')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-c01ed4d984c6> in <module>
# ----> 1 test_eval.get_span_distro(hello,'class', 'Instrumenttypes', 'list')
#
# NameError: name 'hello' is not defined

# %%
test_eval.most_frequent_spans(hello,'tag', 'Tech_Other')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-0fcbcee7cfa9> in <module>
# ----> 1 test_eval.most_frequent_spans(hello,'tag', 'Tech_Other')
#
# AttributeError: 'Evaluator' object has no attribute 'most_frequent_spans'

# %%
testdir = repository('EU_32008R1099', 'None', 'None', 'None', 'Article_06.txt')
test_eval = Evaluator(stat_df)
test_l = test_eval.get_tag_list(hello,'None', 'None')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-decdf7e9d426> in <module>
#       1 testdir = repository('EU_32008R1099', 'None', 'None', 'None', 'Article_06.txt')
#       2 test_eval = Evaluator(stat_df)
# ----> 3 test_l = test_eval.get_tag_list(hello,'None', 'None')
#
# NameError: name 'hello' is not defined

# %%
 test = "Article 6\r\nQuality assessment and reports\r\n1.   Member States shall ensure the quality of the data transmitted.\r\n2.   Every reasonable effort shall be undertaken to ensure coherence between energy data declared in accordance with Annex B and data declared in accordance with Commission Decision 2005/166/EC of 10 February 2005 laying down the rules for implementing Decision No 280/2004/EC of the European Parliament and of the Council concerning a mechanism for monitoring Community greenhouse gas emissions and for implementing the Kyoto Protocol (12).\r\n3.   For the purposes of this Regulation, the following quality assessment dimensions shall apply to the data to be transmitted:\r\n(a)\r\n‘relevance’ shall refer to the degree to which statistics meet current and potential needs of the users;\r\n(b)\r\n‘accuracy’ shall refer to the closeness of estimates to the unknown true values;\r\n(c)\r\n‘timeliness’ shall refer to the delay between the availability of the information and the event or phenomenon it describes;\r\n(d)\r\n‘punctuality’ shall refer to the delay between the date of the release of the data and the target date when it should have been delivered;\r\n(e)\r\n‘accessibility’ and ‘clarity’ shall refer to the conditions and modalities by which users can obtain, use and interpret data;\r\n(f)\r\n‘comparability’ shall refer to the measurement of the impact of differences in applied statistical concepts and measurement tools and procedures where statistics are compared between geographical areas, sectoral domains or over time;\r\n(g)\r\n‘coherence’ shall refer to the adequacy of the data to be reliably combined in different ways and for various uses.\r\n4.   Every five years, Member States shall provide the Commission (Eurostat) with a report on the quality of the data transmitted as well as on any methodological changes that have been made.\r\n5.   Within six months of receipt of a request from the Commission (Eurostat), and in order to allow it to assess the quality of the data transmitted, Member States shall send to the Commission (Eurostat) a report containing any relevant information concerning the implementation of this Regulation.\r\n"

# %%
test[343:348]
# Out:
# 'rules'

# %%
search_dir = repository('None', 'None', 'None', 'section1', 'article1')
testdir_else = repository('None', 'None', 'chapter1', 'section1', 'article1')
search_dir_list = list(search_dir.__dict__.values())
testdir_else_list = list(testdir_else.__dict__.values())
print(search_dir_list)
print(testdir_else_list)
#print([x for x in search_dir_list if x in testdir_else_list and x  != 'None'])
set([x for x in search_dir_list if x != 'None']).issubset(set(testdir_else_list))
# Out:
# ['None', 'None', 'None', 'section1', 'article1']
# ['None', 'None', 'chapter1', 'section1', 'article1']
# True

# %%
list(test_dir.__dict__.values())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-437-519fbd0951be> in <module>
# ----> 1 list(test_dir.__dict__.values())
#
# NameError: name 'test_dir' is not defined

# %%
stat_df.loc[stat_df['Policy'] == 'EU_32019R0631_Title_0_Chapter_0_Section_0_Article_16.','Tags'].iloc[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-8a5f636cc028> in <module>
# ----> 1 stat_df.loc[stat_df['Policy'] == 'EU_32019R0631_Title_0_Chapter_0_Section_0_Article_16.','Tags'].iloc[0]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2228
#    2229             # validate the location
# -> 2230             self._validate_integer(key, axis)
#    2231
#    2232             return self._get_loc(key, axis=axis)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2137         len_axis = len(self.obj._get_axis(axis))
#    2138         if key >= len_axis or key < -len_axis:
# -> 2139             raise IndexError("single positional indexer is out-of-bounds")
#    2140
#    2141     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
text = stat_df.loc[stat_df['Policy'] == 'EU_32008R1099_Title_0_Chapter_0_Section_0_Article_06','Text'].iloc[0]

# %%
text[832:841]
# Out:
# 's of esti'

# %%
subset = stat_df['Tags'][0:2]
for set_ in subset:
    for entry in set_:
        print(entry.class_)
# Out:
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity
# Technologyandapplicationspecificity

# %%
[x for b in subset for x in b if x.class_ == 'Technologyandapplicationspecificity']
# Out:
# [<__main__.tag at 0x7ffa858349d0>,
#  <__main__.tag at 0x7ffac3078910>,
#  <__main__.tag at 0x7ffac3078310>,
#  <__main__.tag at 0x7ffac3078790>,
#  <__main__.tag at 0x7ffac3078b90>,
#  <__main__.tag at 0x7ffac3078490>,
#  <__main__.tag at 0x7ffac30786d0>,
#  <__main__.tag at 0x7ffac3078c90>,
#  <__main__.tag at 0x7ffac3078b50>,
#  <__main__.tag at 0x7ffac3078a90>,
#  <__main__.tag at 0x7ffac3078890>,
#  <__main__.tag at 0x7ffac30787d0>,
#  <__main__.tag at 0x7ffac3078810>,
#  <__main__.tag at 0x7ffac3078ed0>,
#  <__main__.tag at 0x7ffa85834f50>,
#  <__main__.tag at 0x7ffa85834f90>,
#  <__main__.tag at 0x7ffa85834ed0>,
#  <__main__.tag at 0x7ffa85834d50>,
#  <__main__.tag at 0x7ffa85834610>,
#  <__main__.tag at 0x7ffa85834e90>,
#  <__main__.tag at 0x7ffa85834910>,
#  <__main__.tag at 0x7ffa85834650>,
#  <__main__.tag at 0x7ffa858348d0>,
#  <__main__.tag at 0x7ffa85834590>,
#  <__main__.tag at 0x7ffa85834950>,
#  <__main__.tag at 0x7ffa85834990>]

# %%
stat_df['']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-c962d310406b> in <module>
# ----> 1 type(stat_df['Tags'][0][0]) == __main__.tag
#
# NameError: name '__main__' is not defined

# %%
len([x for x in chain.from_iterable(stat_df['Tags']) if type(x)!= str and x.class_ == 'Technologyandapplicationspecificity'])
# Out:
# 1344

# %%
list_ = []
for element in data['_views']['_InitialView']['Token']:
# Out:
# [{'sofa': 1, 'end': 7},
#  {'sofa': 1, 'begin': 7, 'end': 8},
#  {'sofa': 1, 'begin': 8, 'end': 9},
#  {'sofa': 1, 'begin': 11, 'end': 16},
#  {'sofa': 1, 'begin': 17, 'end': 25},
#  {'sofa': 1, 'begin': 26, 'end': 33},
#  {'sofa': 1, 'begin': 34, 'end': 40},
#  {'sofa': 1, 'begin': 41, 'end': 47},
#  {'sofa': 1, 'begin': 49, 'end': 50},
#  {'sofa': 1, 'begin': 50, 'end': 51},
#  {'sofa': 1, 'begin': 51, 'end': 54},
#  {'sofa': 1, 'begin': 54, 'end': 57},
#  {'sofa': 1, 'begin': 58, 'end': 60},
#  {'sofa': 1, 'begin': 61, 'end': 65},
#  {'sofa': 1, 'begin': 66, 'end': 72},
#  {'sofa': 1, 'begin': 73, 'end': 79},
#  {'sofa': 1, 'begin': 80, 'end': 83},
#  {'sofa': 1, 'begin': 84, 'end': 93},
#  {'sofa': 1, 'begin': 94, 'end': 96},
#  {'sofa': 1, 'begin': 97, 'end': 100},
#  {'sofa': 1, 'begin': 101, 'end': 106},
#  {'sofa': 1, 'begin': 107, 'end': 109},
#  {'sofa': 1, 'begin': 110, 'end': 115},
#  {'sofa': 1, 'begin': 116, 'end': 124},
#  {'sofa': 1, 'begin': 125, 'end': 133},
#  {'sofa': 1, 'begin': 134, 'end': 136},
#  {'sofa': 1, 'begin': 137, 'end': 140},
#  {'sofa': 1, 'begin': 141, 'end': 151},
#  {'sofa': 1, 'begin': 152, 'end': 154},
#  {'sofa': 1, 'begin': 155, 'end': 166},
#  {'sofa': 1, 'begin': 166, 'end': 167},
#  {'sofa': 1, 'begin': 168, 'end': 175},
#  {'sofa': 1, 'begin': 504, 'end': 506},
#  {'sofa': 1, 'begin': 507, 'end': 510},
#  {'sofa': 1, 'begin': 511, 'end': 520},
#  {'sofa': 1, 'begin': 521, 'end': 529},
#  {'sofa': 1, 'begin': 530, 'end': 532},
#  {'sofa': 1, 'begin': 533, 'end': 535},
#  {'sofa': 1, 'begin': 536, 'end': 548},
#  {'sofa': 1, 'begin': 549, 'end': 553},
#  {'sofa': 1, 'begin': 554, 'end': 557},
#  {'sofa': 1, 'begin': 558, 'end': 569},
#  {'sofa': 1, 'begin': 570, 'end': 575},
#  {'sofa': 1, 'begin': 576, 'end': 580},
#  {'sofa': 1, 'begin': 581, 'end': 585},
#  {'sofa': 1, 'begin': 585, 'end': 586},
#  {'sofa': 1, 'begin': 587, 'end': 592},
#  {'sofa': 1, 'begin': 593, 'end': 595},
#  {'sofa': 1, 'begin': 596, 'end': 598},
#  {'sofa': 1, 'begin': 599, 'end': 601},
#  {'sofa': 1, 'begin': 602, 'end': 610},
#  {'sofa': 1, 'begin': 611, 'end': 613},
#  {'sofa': 1, 'begin': 614, 'end': 622},
#  {'sofa': 1, 'begin': 623, 'end': 630},
#  {'sofa': 1, 'begin': 631, 'end': 634},
#  {'sofa': 1, 'begin': 635, 'end': 643},
#  {'sofa': 1, 'begin': 644, 'end': 651},
#  {'sofa': 1, 'begin': 652, 'end': 658},
#  {'sofa': 1, 'begin': 659, 'end': 661},
#  {'sofa': 1, 'begin': 662, 'end': 669},
#  {'sofa': 1, 'begin': 670, 'end': 676},
#  {'sofa': 1, 'begin': 677, 'end': 682},
#  {'sofa': 1, 'begin': 683, 'end': 686},
#  {'sofa': 1, 'begin': 687, 'end': 690},
#  {'sofa': 1, 'begin': 691, 'end': 699},
#  {'sofa': 1, 'begin': 700, 'end': 702},
#  {'sofa': 1, 'begin': 703, 'end': 712},
#  {'sofa': 1, 'begin': 713, 'end': 723},
#  {'sofa': 1, 'begin': 724, 'end': 728},
#  {'sofa': 1, 'begin': 729, 'end': 732},
#  {'sofa': 1, 'begin': 733, 'end': 745},
#  {'sofa': 1, 'begin': 746, 'end': 748},
#  {'sofa': 1, 'begin': 749, 'end': 753},
#  {'sofa': 1, 'begin': 754, 'end': 763},
#  {'sofa': 1, 'begin': 763, 'end': 764},
#  {'sofa': 1, 'begin': 766, 'end': 767},
#  {'sofa': 1, 'begin': 767, 'end': 768},
#  {'sofa': 1, 'begin': 768, 'end': 771},
#  {'sofa': 1, 'begin': 771, 'end': 774},
#  {'sofa': 1, 'begin': 775, 'end': 787},
#  {'sofa': 1, 'begin': 788, 'end': 796},
#  {'sofa': 1, 'begin': 797, 'end': 799},
#  {'sofa': 1, 'begin': 800, 'end': 802},
#  {'sofa': 1, 'begin': 803, 'end': 812},
#  {'sofa': 1, 'begin': 812, 'end': 813},
#  {'sofa': 1, 'begin': 813, 'end': 814},
#  {'sofa': 1, 'begin': 815, 'end': 820},
#  {'sofa': 1, 'begin': 820, 'end': 821},
#  {'sofa': 1, 'begin': 823, 'end': 824},
#  {'sofa': 1, 'begin': 824, 'end': 825},
#  {'sofa': 1, 'begin': 1714, 'end': 1717},
#  {'sofa': 1, 'begin': 1718, 'end': 1730},
#  {'sofa': 1, 'begin': 1731, 'end': 1734},
#  {'sofa': 1, 'begin': 1735, 'end': 1738},
#  {'sofa': 1, 'begin': 1739, 'end': 1745},
#  {'sofa': 1, 'begin': 1746, 'end': 1751},
#  {'sofa': 1, 'begin': 1752, 'end': 1762},
#  {'sofa': 1, 'begin': 1763, 'end': 1765},
#  {'sofa': 1, 'begin': 1766, 'end': 1776},
#  {'sofa': 1, 'begin': 1777, 'end': 1781},
#  {'sofa': 1, 'begin': 1782, 'end': 1791},
#  {'sofa': 1, 'begin': 1791, 'end': 1792},
#  {'sofa': 1, 'begin': 1792, 'end': 1793},
#  {'sofa': 1, 'begin': 1793, 'end': 1794},
#  {'sofa': 1, 'begin': 1794, 'end': 1795},
#  {'sofa': 1, 'begin': 1795, 'end': 1796},
#  {'sofa': 1, 'begin': 1796, 'end': 1797}]

# %%
[x['begin'] for x in  data['_views']['_InitialView']['Token']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-3d41dc7301f9> in <module>
# ----> 1 [x['begin'] for x in  data['_views']['_InitialView']['Token']]
#
# <ipython-input-23-3d41dc7301f9> in <listcomp>(.0)
# ----> 1 [x['begin'] for x in  data['_views']['_InitialView']['Token']]
#
# KeyError: 'begin'

# %%
[x['begin'] for x in  data['_views']['_InitialView']['Token'] if int(x['begin']) < 50]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-d7f73de7b671> in <module>
# ----> 1 [x['begin'] for x in  data['_views']['_InitialView']['Token'] if int(x['begin']) < 50]
#
# <ipython-input-21-d7f73de7b671> in <listcomp>(.0)
# ----> 1 [x['begin'] for x in  data['_views']['_InitialView']['Token'] if int(x['begin']) < 50]
#
# KeyError: 'begin'

# %%
list(data['_views']['_InitialView']['Technologyandapplicationspecificity'][0].values())
# Out:
# [1, 57, 88, 'Tech_LowCarbon']

# %%
test_df = pd.DataFrame(columns = ['text'], index = np.arange(0,2))
test_df['text'].loc[0] = 'hello peter ist mee'
test_df['text'].loc[1] = 'why I am su sotun'

# %%
test_df.head()
# Out:
#                   text
# 0  hello peter ist mee
# 1    why I am su sotun

# %%
test_df['text'] = test_df['text'].apply(clean_text)

# %%
len(list(chain.from_iterable(test_df['text'])))
# Out:
# 9

# %%
class Negator(object):
    def __eq__(self,other):
        return not other

thing = Negator()
print(thing == None)    #True
print(thing is None)    #False
# Out:
# True
# False

# %%
hello = 1 if 1 < 2
# Out:
#   File "<ipython-input-199-833455e983d3>", line 1
#     hello = 1 if 1 < 2
#                       ^
# SyntaxError: invalid syntax

# %%
all_tokens = data['_views']['_InitialView']['Token']

# %%
all_tokens
# Out:
# [{'sofa': 1, 'end': 7, 'begin': 0},
#  {'sofa': 1, 'begin': 7, 'end': 8},
#  {'sofa': 1, 'begin': 8, 'end': 10},
#  {'sofa': 1, 'begin': 12, 'end': 21},
#  {'sofa': 1, 'begin': 22, 'end': 24},
#  {'sofa': 1, 'begin': 25, 'end': 28},
#  {'sofa': 1, 'begin': 29, 'end': 35},
#  {'sofa': 1, 'begin': 36, 'end': 42},
#  {'sofa': 1, 'begin': 44, 'end': 45},
#  {'sofa': 1, 'begin': 45, 'end': 46},
#  {'sofa': 1, 'begin': 46, 'end': 49},
#  {'sofa': 1, 'begin': 49, 'end': 53},
#  {'sofa': 1, 'begin': 54, 'end': 60},
#  {'sofa': 1, 'begin': 61, 'end': 66},
#  {'sofa': 1, 'begin': 67, 'end': 72},
#  {'sofa': 1, 'begin': 73, 'end': 79},
#  {'sofa': 1, 'begin': 80, 'end': 81},
#  {'sofa': 1, 'begin': 82, 'end': 88},
#  {'sofa': 1, 'begin': 89, 'end': 91},
#  {'sofa': 1, 'begin': 92, 'end': 95},
#  {'sofa': 1, 'begin': 96, 'end': 106},
#  {'sofa': 1, 'begin': 107, 'end': 109},
#  {'sofa': 1, 'begin': 110, 'end': 118},
#  {'sofa': 1, 'begin': 119, 'end': 121},
#  {'sofa': 1, 'begin': 122, 'end': 125},
#  {'sofa': 1, 'begin': 126, 'end': 135},
#  {'sofa': 1, 'begin': 136, 'end': 139},
#  {'sofa': 1, 'begin': 140, 'end': 143},
#  {'sofa': 1, 'begin': 144, 'end': 146},
#  {'sofa': 1, 'begin': 147, 'end': 153},
#  {'sofa': 1, 'begin': 154, 'end': 158},
#  {'sofa': 1, 'begin': 159, 'end': 168},
#  {'sofa': 1, 'begin': 169, 'end': 176},
#  {'sofa': 1, 'begin': 177, 'end': 179},
#  {'sofa': 1, 'begin': 180, 'end': 182},
#  {'sofa': 1, 'begin': 182, 'end': 183},
#  {'sofa': 1, 'begin': 183, 'end': 191},
#  {'sofa': 1, 'begin': 192, 'end': 196},
#  {'sofa': 1, 'begin': 196, 'end': 197},
#  {'sofa': 1, 'begin': 198, 'end': 201},
#  {'sofa': 1, 'begin': 202, 'end': 207},
#  {'sofa': 1, 'begin': 208, 'end': 211},
#  {'sofa': 1, 'begin': 212, 'end': 217},
#  {'sofa': 1, 'begin': 218, 'end': 228},
#  {'sofa': 1, 'begin': 228, 'end': 229},
#  {'sofa': 1, 'begin': 230, 'end': 233},
#  {'sofa': 1, 'begin': 234, 'end': 239},
#  {'sofa': 1, 'begin': 240, 'end': 246},
#  {'sofa': 1, 'begin': 246, 'end': 247},
#  {'sofa': 1, 'begin': 248, 'end': 250},
#  {'sofa': 1, 'begin': 251, 'end': 253},
#  {'sofa': 1, 'begin': 254, 'end': 263},
#  {'sofa': 1, 'begin': 264, 'end': 266},
#  {'sofa': 1, 'begin': 267, 'end': 269},
#  {'sofa': 1, 'begin': 269, 'end': 270},
#  {'sofa': 1, 'begin': 270, 'end': 278},
#  {'sofa': 1, 'begin': 279, 'end': 283},
#  {'sofa': 1, 'begin': 283, 'end': 284},
#  {'sofa': 1, 'begin': 285, 'end': 290},
#  {'sofa': 1, 'begin': 291, 'end': 293},
#  {'sofa': 1, 'begin': 294, 'end': 297},
#  {'sofa': 1, 'begin': 298, 'end': 302},
#  {'sofa': 1, 'begin': 303, 'end': 309},
#  {'sofa': 1, 'begin': 310, 'end': 318},
#  {'sofa': 1, 'begin': 318, 'end': 319},
#  {'sofa': 1, 'begin': 321, 'end': 324},
#  {'sofa': 1, 'begin': 325, 'end': 331},
#  {'sofa': 1, 'begin': 332, 'end': 337},
#  {'sofa': 1, 'begin': 338, 'end': 344},
#  {'sofa': 1, 'begin': 344, 'end': 345},
#  {'sofa': 1, 'begin': 346, 'end': 348},
#  {'sofa': 1, 'begin': 349, 'end': 359},
#  {'sofa': 1, 'begin': 359, 'end': 360},
#  {'sofa': 1, 'begin': 362, 'end': 363},
#  {'sofa': 1, 'begin': 363, 'end': 364},
#  {'sofa': 1, 'begin': 364, 'end': 365},
#  {'sofa': 1, 'begin': 367, 'end': 370},
#  {'sofa': 1, 'begin': 371, 'end': 379},
#  {'sofa': 1, 'begin': 380, 'end': 381},
#  {'sofa': 1, 'begin': 381, 'end': 392},
#  {'sofa': 1, 'begin': 392, 'end': 393},
#  {'sofa': 1, 'begin': 394, 'end': 401},
#  {'sofa': 1, 'begin': 402, 'end': 405},
#  {'sofa': 1, 'begin': 406, 'end': 413},
#  {'sofa': 1, 'begin': 413, 'end': 414},
#  {'sofa': 1, 'begin': 415, 'end': 418},
#  {'sofa': 1, 'begin': 418, 'end': 419},
#  {'sofa': 1, 'begin': 419, 'end': 428},
#  {'sofa': 1, 'begin': 428, 'end': 429},
#  {'sofa': 1, 'begin': 430, 'end': 433},
#  {'sofa': 1, 'begin': 434, 'end': 441},
#  {'sofa': 1, 'begin': 442, 'end': 448},
#  {'sofa': 1, 'begin': 449, 'end': 451},
#  {'sofa': 1, 'begin': 452, 'end': 458},
#  {'sofa': 1, 'begin': 459, 'end': 463},
#  {'sofa': 1, 'begin': 464, 'end': 473},
#  {'sofa': 1, 'begin': 474, 'end': 481},
#  {'sofa': 1, 'begin': 482, 'end': 484},
#  {'sofa': 1, 'begin': 485, 'end': 488},
#  {'sofa': 1, 'begin': 489, 'end': 498},
#  {'sofa': 1, 'begin': 499, 'end': 502},
#  {'sofa': 1, 'begin': 503, 'end': 511},
#  {'sofa': 1, 'begin': 512, 'end': 517},
#  {'sofa': 1, 'begin': 518, 'end': 521},
#  {'sofa': 1, 'begin': 522, 'end': 525},
#  {'sofa': 1, 'begin': 526, 'end': 534},
#  {'sofa': 1, 'begin': 535, 'end': 540},
#  {'sofa': 1, 'begin': 541, 'end': 543},
#  {'sofa': 1, 'begin': 544, 'end': 551},
#  {'sofa': 1, 'begin': 552, 'end': 554},
#  {'sofa': 1, 'begin': 555, 'end': 563},
#  {'sofa': 1, 'begin': 564, 'end': 569},
#  {'sofa': 1, 'begin': 570, 'end': 572},
#  {'sofa': 1, 'begin': 573, 'end': 580},
#  {'sofa': 1, 'begin': 581, 'end': 584},
#  {'sofa': 1, 'begin': 585, 'end': 591},
#  {'sofa': 1, 'begin': 592, 'end': 594},
#  {'sofa': 1, 'begin': 595, 'end': 601},
#  {'sofa': 1, 'begin': 602, 'end': 606},
#  {'sofa': 1, 'begin': 607, 'end': 616},
#  {'sofa': 1, 'begin': 617, 'end': 624},
#  {'sofa': 1, 'begin': 625, 'end': 631},
#  {'sofa': 1, 'begin': 632, 'end': 636},
#  {'sofa': 1, 'begin': 637, 'end': 644},
#  {'sofa': 1, 'begin': 645, 'end': 648},
#  {'sofa': 1, 'begin': 649, 'end': 659},
#  {'sofa': 1, 'begin': 660, 'end': 670},
#  {'sofa': 1, 'begin': 671, 'end': 673},
#  {'sofa': 1, 'begin': 674, 'end': 678},
#  {'sofa': 1, 'begin': 679, 'end': 680},
#  {'sofa': 1, 'begin': 681, 'end': 683},
#  {'sofa': 1, 'begin': 684, 'end': 689},
#  {'sofa': 1, 'begin': 689, 'end': 690},
#  {'sofa': 1, 'begin': 690, 'end': 691},
#  {'sofa': 1, 'begin': 691, 'end': 692},
#  {'sofa': 1, 'begin': 693, 'end': 695},
#  {'sofa': 1, 'begin': 696, 'end': 706},
#  {'sofa': 1, 'begin': 707, 'end': 711},
#  {'sofa': 1, 'begin': 712, 'end': 719},
#  {'sofa': 1, 'begin': 719, 'end': 720},
#  {'sofa': 1, 'begin': 720, 'end': 721},
#  {'sofa': 1, 'begin': 721, 'end': 722},
#  {'sofa': 1, 'begin': 724, 'end': 725},
#  {'sofa': 1, 'begin': 725, 'end': 726},
#  {'sofa': 1, 'begin': 726, 'end': 727},
#  {'sofa': 1, 'begin': 729, 'end': 732},
#  {'sofa': 1, 'begin': 733, 'end': 745},
#  {'sofa': 1, 'begin': 746, 'end': 749},
#  {'sofa': 1, 'begin': 750, 'end': 761},
#  {'sofa': 1, 'begin': 762, 'end': 764},
#  {'sofa': 1, 'begin': 765, 'end': 772},
#  {'sofa': 1, 'begin': 773, 'end': 780},
#  {'sofa': 1, 'begin': 781, 'end': 784},
#  {'sofa': 1, 'begin': 785, 'end': 790},
#  {'sofa': 1, 'begin': 791, 'end': 799},
#  {'sofa': 1, 'begin': 800, 'end': 802},
#  {'sofa': 1, 'begin': 803, 'end': 810},
#  {'sofa': 1, 'begin': 811, 'end': 817},
#  {'sofa': 1, 'begin': 818, 'end': 822},
#  {'sofa': 1, 'begin': 823, 'end': 832},
#  {'sofa': 1, 'begin': 833, 'end': 840},
#  {'sofa': 1, 'begin': 840, 'end': 841},
#  {'sofa': 1, 'begin': 842, 'end': 845},
#  {'sofa': 1, 'begin': 846, 'end': 849},
#  {'sofa': 1, 'begin': 850, 'end': 862},
#  {'sofa': 1, 'begin': 863, 'end': 865},
#  {'sofa': 1, 'begin': 866, 'end': 869},
#  {'sofa': 1, 'begin': 870, 'end': 878},
#  {'sofa': 1, 'begin': 879, 'end': 883},
#  {'sofa': 1, 'begin': 884, 'end': 888},
#  {'sofa': 1, 'begin': 889, 'end': 896},
#  {'sofa': 1, 'begin': 897, 'end': 899},
#  {'sofa': 1, 'begin': 900, 'end': 905},
#  {'sofa': 1, 'begin': 906, 'end': 909},
#  {'sofa': 1, 'begin': 910, 'end': 913},
#  {'sofa': 1, 'begin': 914, 'end': 916},
#  {'sofa': 1, 'begin': 917, 'end': 920},
#  {'sofa': 1, 'begin': 921, 'end': 927},
#  {'sofa': 1, 'begin': 928, 'end': 933},
#  {'sofa': 1, 'begin': 933, 'end': 934},
#  {'sofa': 1, 'begin': 934, 'end': 935},
#  {'sofa': 1, 'begin': 3958, 'end': 3959},
#  {'sofa': 1, 'begin': 3960, 'end': 3962},
#  {'sofa': 1, 'begin': 3964, 'end': 3965},
#  {'sofa': 1, 'begin': 3965, 'end': 3966},
#  {'sofa': 1, 'begin': 3966, 'end': 3967},
#  {'sofa': 1, 'begin': 3969, 'end': 3977},
#  {'sofa': 1, 'begin': 3978, 'end': 3990},
#  {'sofa': 1, 'begin': 3991, 'end': 4000},
#  {'sofa': 1, 'begin': 4001, 'end': 4009},
#  {'sofa': 1, 'begin': 4010, 'end': 4013},
#  {'sofa': 1, 'begin': 4014, 'end': 4026},
#  {'sofa': 1, 'begin': 4027, 'end': 4029},
#  {'sofa': 1, 'begin': 4030, 'end': 4036},
#  {'sofa': 1, 'begin': 4037, 'end': 4041},
#  {'sofa': 1, 'begin': 4042, 'end': 4051},
#  {'sofa': 1, 'begin': 4052, 'end': 4059},
#  {'sofa': 1, 'begin': 4060, 'end': 4062},
#  {'sofa': 1, 'begin': 4063, 'end': 4071},
#  {'sofa': 1, 'begin': 4072, 'end': 4080},
#  {'sofa': 1, 'begin': 4081, 'end': 4084},
#  {'sofa': 1, 'begin': 4085, 'end': 4088},
#  {'sofa': 1, 'begin': 4089, 'end': 4092},
#  {'sofa': 1, 'begin': 4093, 'end': 4106},
#  {'sofa': 1, 'begin': 4107, 'end': 4109},
#  {'sofa': 1, 'begin': 4110, 'end': 4118},
#  {'sofa': 1, 'begin': 4119, 'end': 4126},
#  {'sofa': 1, 'begin': 4127, 'end': 4130},
#  {'sofa': 1, 'begin': 4131, 'end': 4138},
#  {'sofa': 1, 'begin': 4138, 'end': 4139},
#  {'sofa': 1, 'begin': 4141, 'end': 4142},
#  {'sofa': 1, 'begin': 4142, 'end': 4143},
#  {'sofa': 1, 'begin': 4143, 'end': 4146},
#  {'sofa': 1, 'begin': 4146, 'end': 4148},
#  {'sofa': 1, 'begin': 4149, 'end': 4153},
#  {'sofa': 1, 'begin': 4154, 'end': 4160},
#  {'sofa': 1, 'begin': 4161, 'end': 4164},
#  {'sofa': 1, 'begin': 4165, 'end': 4171},
#  {'sofa': 1, 'begin': 4172, 'end': 4177},
#  {'sofa': 1, 'begin': 4178, 'end': 4181},
#  {'sofa': 1, 'begin': 4182, 'end': 4189},
#  {'sofa': 1, 'begin': 4190, 'end': 4193},
#  {'sofa': 1, 'begin': 4194, 'end': 4198},
#  {'sofa': 1, 'begin': 4199, 'end': 4201},
#  {'sofa': 1, 'begin': 4202, 'end': 4205},
#  {'sofa': 1, 'begin': 4206, 'end': 4214},
#  {'sofa': 1, 'begin': 4215, 'end': 4222},
#  {'sofa': 1, 'begin': 4222, 'end': 4223}]

# %%
all_tokens[0]['begin'] = 0
start = 34
end = 47

# %%
[x for x in all_tokens if  x['begin'] >= start and x['end'] <= end]
# Out:
# [{'sofa': 1, 'begin': 36, 'end': 42},
#  {'sofa': 1, 'begin': 44, 'end': 45},
#  {'sofa': 1, 'begin': 45, 'end': 46}]

# %%
ls = [token(x['begin'], x['end'], data['_referenced_fss']['1']['sofaString'][x['begin']:x['end']]) for x in all_tokens if  x['begin'] >= start and x['end'] <= end]

# %%
ls[2].text
# Out:
# '.'

# %%
[x for x in all_tokens if x['begin'] > 34]
# Out:
# [{'sofa': 1, 'begin': 41, 'end': 47},
#  {'sofa': 1, 'begin': 49, 'end': 50},
#  {'sofa': 1, 'begin': 50, 'end': 51}]

# %%
data['_referenced_fss']['1']['sofaString'][34:47]
# Out:
# 'Member States\r'

# %%
data['_views']['_InitialView']['Policydesigncharacteristics']
# Out:
# [{'sofa': 1, 'begin': 34, 'end': 47, 'Actor': 'Addressee_default'},
#  {'sofa': 1, 'begin': 66, 'end': 79, 'Actor': 'Addressee_default'},
#  {'sofa': 1, 'begin': 247, 'end': 264, 'Actor': 'Addressee_sector'},
#  {'sofa': 1, 'begin': 272, 'end': 285, 'Actor': 'Addressee_monitored'},
#  {'sofa': 1, 'begin': 303, 'end': 313, 'Actor': 'Authority_monitoring'},
#  {'sofa': 1, 'begin': 345, 'end': 658, 'Resource': 'Resource_Other'},
#  {'sofa': 1, 'begin': 635, 'end': 658, 'Objective': 'Objective_QualIntention'},
#  {'sofa': 1, 'begin': 670, 'end': 682, 'Actor': 'Addressee_resource'},
#  {'sofa': 1, 'begin': 703, 'end': 723, 'Compliance': 'Form_monitoring'},
#  {'sofa': 1, 'begin': 828, 'end': 903, 'Compliance': 'Form_monitoring'},
#  {'sofa': 1, 'begin': 911, 'end': 1107, 'Compliance': 'Form_monitoring'},
#  {'sofa': 1, 'begin': 911, 'end': 1011, 'Compliance': 'Form_monitoring'},
#  {'sofa': 1, 'begin': 947, 'end': 1083, 'Resource': 'Resource_Other'},
#  {'sofa': 1,
#   'begin': 1060,
#   'end': 1083,
#   'Objective': 'Objective_QualIntention'},
#  {'sofa': 1, 'begin': 1095, 'end': 1107, 'Actor': 'Addressee_resource'},
#  {'sofa': 1, 'begin': 1128, 'end': 1140, 'Actor': 'Addressee_resource'},
#  {'sofa': 1, 'begin': 1261, 'end': 1353, 'Resource': 'Resource_Other'},
#  {'sofa': 1,
#   'begin': 1396,
#   'end': 1419,
#   'Objective': 'Objective_QualIntention'},
#  {'sofa': 1, 'begin': 1433, 'end': 1445, 'Actor': 'Addressee_resource'},
#  {'sofa': 1, 'begin': 1501, 'end': 1523, 'Time': 'Time_PolDuration'},
#  {'sofa': 1, 'begin': 1543, 'end': 1579, 'Time': 'Time_PolDuration'},
#  {'sofa': 1, 'begin': 1694, 'end': 1706, 'Actor': 'Addressee_default'},
#  {'sofa': 1, 'begin': 1739, 'end': 1751, 'Actor': 'Addressee_resource'}]

# %%
text = 'hello'
text[:2]
# Out:
# 'he'

# %%
token
# Out:
# {'sofa': 1, 'begin': 8, 'end': 9}

# %%
# Out:
# __main__.token

# %%
token_1 = token(2,3,'hello')
token_2 = token(3,4,'peter')

# %%
list_l = []
list_l.append(token_1)
list_l.append(token_2)

# %%
list_l
# Out:
# [start:2 stop:3 text:hello, start:3 stop:4 text:peter]

# %%
list_l[0].text = 'sick'

# %%
token_1
# Out:
# start:2 stop:3 text:sick
