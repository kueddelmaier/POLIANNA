# %% [markdown]
# # Notebook to Test all the functions

# %% [markdown]
# ## First only the corpus ##

# %%
import sys
import pandas as pd
import collections 
import os
import numpy as np
from itertools import chain
from itertools import combinations
sys.path.append('/home/jkuettel/NLP_spark/src')
sys.path.append('/home/jkuettel/NLP_spark')
from src.experiment_utils.helper_classes import token, span, repository
from src.d02_corpus_statistics.corpus import Corpus
from src.d03_inter_annotator_agreement.inter_annotator_agremment import Inter_Annotator_Agreement, _get_score_article


from definitions import ROOT_DIR

# %% [markdown]
# ## Test all corpus funtions

# %%
    
dataframe_dir = os.path.join(ROOT_DIR,'data/02_processed_to_dataframe', 'preprocessed_dataframe.pkl')
stat_df = pd.read_pickle(dataframe_dir)
stat_df.head()
# Out:
#                                                    Policy  \
# EU_32006L0032_Title_0_Chapter_1_Section_0_Artic...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...
# EU_32019L0944_Title_0_Chapter_6_Section_3_Artic...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...
#
#                                                                                                  Text  \
# EU_32006L0032_Title_0_Chapter_1_Section_0_Artic...  article 3\r\ndefinitions\r\nfor the purposes o...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...  article 25\r\npenalties\r\nmember states shall...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...  article 7\r\njoint projects between member sta...
# EU_32019L0944_Title_0_Chapter_6_Section_3_Artic...  article 47\r\nindependence of the transmission...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  article 14\r\nadjustment of m0 and tm0 values\...
#
#                                                                                                Tokens  \
# EU_32006L0032_Title_0_Chapter_1_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32019L0944_Title_0_Chapter_6_Section_3_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
#
#                                                         Article_State  \
# EU_32006L0032_Title_0_Chapter_1_Section_0_Artic...  CURATION_FINISHED
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...  CURATION_FINISHED
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...  CURATION_FINISHED
# EU_32019L0944_Title_0_Chapter_6_Section_3_Artic...  CURATION_FINISHED
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  CURATION_FINISHED
#
#                                                    Finished_Annotators  \
# EU_32006L0032_Title_0_Chapter_1_Section_0_Artic...     [Fride, Onerva]
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...     [Fride, Onerva]
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...    [Alisha, Fabian]
# EU_32019L0944_Title_0_Chapter_6_Section_3_Artic...    [Alisha, Onerva]
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...    [Onerva, Fabian]
#
#                                                                                              Curation  \
# EU_32006L0032_Title_0_Chapter_1_Section_0_Artic...  [annotator:curation layer:Instrumenttypes type...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...  [annotator:curation layer:Instrumenttypes type...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...  [annotator:curation layer:Policydesigncharacte...
# EU_32019L0944_Title_0_Chapter_6_Section_3_Artic...  [annotator:curation layer:Instrumenttypes type...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  [annotator:curation layer:Instrumenttypes type...
#
#                                                                                                Onerva  \
# EU_32006L0032_Title_0_Chapter_1_Section_0_Artic...  [annotator:Onerva layer:Instrumenttypes type:I...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...  [annotator:Onerva layer:Instrumenttypes type:I...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...                                                 []
# EU_32019L0944_Title_0_Chapter_6_Section_3_Artic...  [annotator:Onerva layer:Instrumenttypes type:I...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  [annotator:Onerva layer:Instrumenttypes type:I...
#
#                                                                                                 Fride  \
# EU_32006L0032_Title_0_Chapter_1_Section_0_Artic...  [annotator:Fride layer:Instrumenttypes type:In...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...  [annotator:Fride layer:Instrumenttypes type:In...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...
# EU_32019L0944_Title_0_Chapter_6_Section_3_Artic...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...
#
#                                                    Lynn Sebastian  \
# EU_32006L0032_Title_0_Chapter_1_Section_0_Artic...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...   []
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...             []
# EU_32019L0944_Title_0_Chapter_6_Section_3_Artic...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...
#
#                                                                                                Alisha  \
# EU_32006L0032_Title_0_Chapter_1_Section_0_Artic...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...  [annotator:Alisha layer:Policydesigncharacteri...
# EU_32019L0944_Title_0_Chapter_6_Section_3_Artic...  [annotator:Alisha layer:Instrumenttypes type:I...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...
#
#                                                                                                Fabian
# EU_32006L0032_Title_0_Chapter_1_Section_0_Artic...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...  [annotator:Fabian layer:Policydesigncharacteri...
# EU_32019L0944_Title_0_Chapter_6_Section_3_Artic...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  [annotator:Fabian layer:Policydesigncharacteri...

# %%
test_corpus = Corpus(stat_df)
#test_dir = repository(policy = 'EU_32008R1099', title = 'None', chapter = 'None', section = 'None', article = 'None')
test_dir = test_corpus.df['Curation'][1][0].rep

# %% [markdown]
# ## testing get_span_list ##

# %%
len(test_corpus._get_iterator_conditional_rep(test_dir, ['Fabian', 'Onerva'])) == len(test_corpus.df['Fabian'][1]) + len(test_corpus.df['Onerva'][1])
# Out:
# True

# %%
#multiple colums
len(test_corpus._get_iterator_conditional_rep(test_dir, ['Fabian', 'Onerva']))
# Out:
# 11

# %%
len(test_corpus.df['Onerva'][1]) + len(test_corpus.df['Fabian'][1])
# Out:
# 11

# %%
len(test_corpus.get_span_list(test_dir, ['Fabian']))
# Out:
# 0

# %%
len(test_corpus.df['Fabian'][1])
# Out:
# 26

# %% [markdown]
# ## get_span_distro

# %%
span_list = test_corpus.get_span_list(test_dir, ['Fabian', 'Onerva'])

print(len([span_.text for span_ in span_list if  len(span_.text) == 12]))
# Out:
# 4

# %%
print(len([span_.text for span_ in span_list if  len(span_.text) == 25]))
# Out:
# 7

# %%
print(len([span_.text for span_ in span_list if  len(span_.text) == 51]))
# Out:
# 2

# %%
test_corpus.get_span_distro(test_dir, ['Onerva', 'Fabian'], level= 'character')
# Out:
# {10: 18,
#  14: 7,
#  25: 7,
#  27: 6,
#  26: 5,
#  7: 4,
#  12: 4,
#  6: 3,
#  18: 3,
#  8: 3,
#  9: 2,
#  20: 2,
#  51: 2,
#  13: 2,
#  32: 2,
#  11: 1,
#  41: 1,
#  49: 1,
#  34: 1,
#  4: 1,
#  58: 1,
#  29: 1,
#  36: 1,
#  46: 1,
#  33: 1,
#  75: 1,
#  19: 1,
#  24: 1}

# %% [markdown]
# ## get_token_list_from_repository

# %%
test_corpus.get_token_list_from_repository(test_dir) == test_corpus.df['Tokens'][1]
# Out:
# True

# %% [markdown]
# ## get_token_count_from_repository

# %%
test_corpus.get_token_count_from_repository(test_dir) == len(test_corpus.df['Tokens'][1])
# Out:
# True

# %% [markdown]
# ## get_tokens_from_span_list

# %%
all_tokens = list(chain.from_iterable([x.tokens for x in test_corpus.get_span_list(test_dir, ['Fabian'])]))
test_corpus.get_tokens_from_span_list(test_dir, ['Fabian']) == all_tokens
# Out:
# True

# %% [markdown]
# ## get_token_count_from_span_list

# %%
 test_corpus.get_token_count_from_span_list(test_dir, ['Fabian', 'Onerva']) == len(test_corpus.get_tokens_from_span_list(test_dir, ['Fabian', 'Onerva']))
# Out:
# True

# %% [markdown]
# ## most_frequent_labeled_tokens

# %%
len([x for x in test_corpus.get_tokens_from_span_list(test_dir, ['Fabian', 'Onerva']) if x.text == 'commission' ])
# Out:
# 16

# %%
len([x for x in test_corpus.get_tokens_from_span_list(test_dir, ['Fabian', 'Onerva']) if x.text == 'consumption'])
# Out:
# 12

# %%
len([x for x in test_corpus.get_tokens_from_span_list(test_dir, ['Fabian', 'Onerva']) if x.text == 'regulation'])
# Out:
# 4

# %%
test_corpus.most_frequent_labeled_tokens(test_dir, ['Fabian', 'Onerva'])
# Out:
# {'commission': 16,
#  'fuel': 14,
#  'energy': 14,
#  'and': 13,
#  'consumption': 12,
#  'or': 10,
#  'vehicles': 10,
#  'no': 6,
#  '\xa0': 6,
#  '/': 6,
#  'passenger': 6,
#  'cars': 6,
#  'light': 6,
#  'commercial': 6,
#  'monitor': 4,
#  'assess': 4,
#  'regulation': 4,
#  '(': 4,
#  'ec': 4,
#  ')': 4,
#  '715': 4,
#  '2007': 4,
#  'data': 4,
#  'emissions': 4,
#  '1': 4,
#  'electric': 4,
#  'co2': 3,
#  '2021': 3,
#  'vehicle': 3,
#  'collect': 2,
#  'the': 2,
#  'real-world': 2,
#  'from': 2,
#  'january': 2,
#  'manufacturers': 2,
#  'later': 2,
#  'than': 2,
#  'june': 2,
#  '2023': 2,
#  'report': 2,
#  'annually': 2,
#  'hybrid': 2,
#  'mechanism': 2,
#  'values': 2,
#  'parameters': 2,
#  'manufacturer': 2,
#  'gap': 2,
#  'new': 2,
#  'consumed': 2,
#  'on': 1,
#  'to': 1,
#  '2026': 1,
#  'obligations': 1,
#  'legislative': 1,
#  'proposal': 1,
#  'national': 1,
#  'authorities': 1,
#  'create': 1,
#  'anonymised': 1,
#  'aggregated': 1,
#  'datasets': 1,
#  'prevent': 1,
#  'growing': 1,
#  'preventing': 1,
#  'an': 1,
#  'increase': 1,
#  'in': 1,
#  'that': 1,
#  '2027': 1,
#  "manufacturer's": 1,
#  'on-board': 1,
#  'monitoring': 1,
#  'devices': 1,
#  'externally': 1,
#  'chargeable': 1}

# %% [markdown]
# ## get_label_count_per_token_distro

# %%
label_counts = [x.tag_count for x in test_corpus.get_token_list_from_repository(test_dir)]
for i in range(0,10):
    print(i, ':', label_counts.count(i))
# Out:
# 0 : 345
# 1 : 15
# 2 : 58
# 3 : 69
# 4 : 22
# 5 : 4
# 6 : 2
# 7 : 0
# 8 : 0
# 9 : 0

# %%
test_corpus.get_label_count_per_token_distro(test_dir)
# Out:
# {0: 345, 1: 15, 2: 58, 3: 69, 4: 22, 5: 4, 6: 2}

# %%
test_corpus.get_tokens_with_label_count(test_dir, 6)
# Out:
# [start:1959 stop:1963 text:fuel tag_count:6,
#  start:1968 stop:1974 text:energy tag_count:6]

# %% [markdown]
# # Inter Annotator Agreement

# %% [markdown]
# ## First test Inter_annotator_agreement based on df

# %%
test_evaluator = Inter_Annotator_Agreement(stat_df)

scoring_metrics = ['f1_exact', 'f1_tokenwise', 'f1_partial', 'f1_heuristic'] #, 'pygamma']

# %%
test_evaluator.append_total_score_per_article(scoring_metrics)
# Out:
# INFO: Pandarallel will run on 48 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
test_evaluator.append_total_score_per_article_no_parallel(scoring_metrics)
# Out:
# 100%|██████████| 448/448 [00:05<00:00, 87.57it/s]
# 100%|██████████| 448/448 [00:04<00:00, 91.74it/s]
# 100%|██████████| 448/448 [00:04<00:00, 91.09it/s]
# 100%|██████████| 448/448 [00:00<00:00, 1337.72it/s]

# %%
test_evaluator.df.head()
# Out:
#                                                    Policy  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...
#
#                                                                                                  Text  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  article 43\r\nexercise of the delegation\r\n1....
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  article 12\r\nreal-world co2 emissions and fue...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  article 11\r\njoint projects between member st...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  article 56\r\namendments to directive (eu) 201...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  article 3\r\nbinding overall union target for ...
#
#                                                                                                Tokens  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
#
#                                                                                              Curation  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  [annotator:curation layer:Instrumenttypes type...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [annotator:curation layer:Instrumenttypes type...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [annotator:curation layer:Instrumenttypes type...
#
#                                                                                                Alisha  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  [annotator:Alisha layer:Instrumenttypes type:I...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  [annotator:Alisha layer:Policydesigncharacteri...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...
#
#                                                                                                 Fride  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  [annotator:Fride layer:Policydesigncharacteris...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [annotator:Fride layer:Instrumenttypes type:In...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  [annotator:Fride layer:Policydesigncharacteris...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [annotator:Fride layer:Instrumenttypes type:In...
#
#                                                                                                Onerva  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  [annotator:Onerva layer:Instrumenttypes type:I...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [annotator:Onerva layer:Instrumenttypes type:I...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [annotator:Onerva layer:Instrumenttypes type:I...
#
#                                                                                                Fabian  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  [annotator:Fabian layer:Policydesigncharacteri...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [annotator:Fabian layer:Instrumenttypes type:I...
#
#                                                    Lynn Sebastian  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...
#
#                                                     f1_exact_score  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...        0.218750
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...        0.289157
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...        0.567308
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...        0.736842
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...        0.420198
#
#                                                     f1_tokenwise_score  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...            0.226574
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...            0.263793
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...            0.512946
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...            0.583333
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...            0.410204
#
#                                                     f1_partial_score  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...          0.281250
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...          0.409639
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...          0.653846
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...          0.736842
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...          0.532749
#
#                                                     f1_heuristic_score
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...            0.281250
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...            0.421603
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...            0.653846
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...            0.736842
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...            0.544437

# %%
#test all articles
scoring_metrics = ['f1_exact', 'f1_tokenwise', 'f1_partial', 'f1_heuristic']

for index, row in test_evaluator.df.iterrows():

    repo = repository.from_repository_name(index)
    span_list = test_evaluator.get_span_list(repo, columns = 'annotators')

    for scoring_metric in scoring_metrics:
        get_span_score = test_evaluator.get_score_spanlist(span_list, scoring_metric)
        score_df = row[scoring_metric + '_score']
        if np.round(get_span_score, 3) != np.round(score_df, 3):
            print(index)
            print('metric', scoring_metric, ' span_score:', get_span_score)
            print('metric', scoring_metric,' df_score:' , score_df)
            print('-----------------------')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-49d5b4d08831> in <module>
#       8
#       9     for scoring_metric in scoring_metrics:
# ---> 10         get_span_score = test_evaluator.get_score_spanlist(span_list, scoring_metric)
#      11         score_df = row[scoring_metric + '_score']
#      12         if np.round(get_span_score, 3) != np.round(score_df, 3):
#
# ~/NLP_spark/src/d03_inter_annotator_agreement/inter_annotator_agremment.py in get_score_spanlist(self, span_list, scoring_metric, weight_by_tokens, **optional_tuple_properties)
#     191             total_tokens += n_tokens
#     192
# --> 193         return total_score / total_tokens
#     194
#     195
#
# ZeroDivisionError: division by zero

# %%
#test all articles
scoring_metrics = ['f1_exact', 'f1_tokenwise', 'f1_partial', 'f1_heuristic']

for index, row in test_evaluator.df.iterrows():

    repo = repository.from_repository_name(index)
    span_list = test_evaluator.get_span_list(repo, columns = 'annotators')

    for scoring_metric in scoring_metrics:
        get_span_score = test_evaluator.get_score_spanlist(span_list, scoring_metric)
        score_df = row[scoring_metric + '_score']
        if np.round(get_span_score, 3) != np.round(score_df, 3):
            print(index)
            print('metric', scoring_metric, ' span_score:', get_span_score)
            print('metric', scoring_metric,' df_score:' , score_df)
            print('-----------------------')
# Out:
# EU_32006L0066_Title_0_Chapter_0_Section_0_Article_30
# metric f1_exact  span_score: 1.0
# metric f1_exact  df_score: nan
# -----------------------
# EU_32006L0066_Title_0_Chapter_0_Section_0_Article_30
# metric f1_tokenwise  span_score: 1.0
# metric f1_tokenwise  df_score: nan
# -----------------------
# EU_32006L0066_Title_0_Chapter_0_Section_0_Article_30
# metric f1_partial  span_score: 1.0
# metric f1_partial  df_score: nan
# -----------------------
# EU_32006L0066_Title_0_Chapter_0_Section_0_Article_30
# metric f1_heuristic  span_score: 1.0
# metric f1_heuristic  df_score: nan
# -----------------------
# EU_32008R1099_Title_0_Chapter_0_Section_0_Article_12
# metric f1_exact  span_score: 0.5
# metric f1_exact  df_score: nan
# -----------------------
# EU_32008R1099_Title_0_Chapter_0_Section_0_Article_12
# metric f1_tokenwise  span_score: 0.8026224982746722
# metric f1_tokenwise  df_score: nan
# -----------------------
# EU_32008R1099_Title_0_Chapter_0_Section_0_Article_12
# metric f1_partial  span_score: 1.0
# metric f1_partial  df_score: nan
# -----------------------
# EU_32008R1099_Title_0_Chapter_0_Section_0_Article_12
# metric f1_heuristic  span_score: 1.0
# metric f1_heuristic  df_score: nan
# -----------------------
# EU_32018R1999_Title_0_Chapter_7_Section_3_Article_50
# metric f1_exact  span_score: 0.5
# metric f1_exact  df_score: nan
# -----------------------
# EU_32018R1999_Title_0_Chapter_7_Section_3_Article_50
# metric f1_tokenwise  span_score: 0.5
# metric f1_tokenwise  df_score: nan
# -----------------------
# EU_32018R1999_Title_0_Chapter_7_Section_3_Article_50
# metric f1_partial  span_score: 0.5
# metric f1_partial  df_score: nan
# -----------------------
# EU_32018R1999_Title_0_Chapter_7_Section_3_Article_50
# metric f1_heuristic  span_score: 0.5
# metric f1_heuristic  df_score: nan
# -----------------------
# EU_32018R1999_Title_0_Chapter_7_Section_3_Article_49
# metric f1_exact  span_score: 1.0
# metric f1_exact  df_score: nan
# -----------------------
# EU_32018R1999_Title_0_Chapter_7_Section_3_Article_49
# metric f1_tokenwise  span_score: 1.0
# metric f1_tokenwise  df_score: nan
# -----------------------
# EU_32018R1999_Title_0_Chapter_7_Section_3_Article_49
# metric f1_partial  span_score: 1.0
# metric f1_partial  df_score: nan
# -----------------------
# EU_32018R1999_Title_0_Chapter_7_Section_3_Article_49
# metric f1_heuristic  span_score: 1.0
# metric f1_heuristic  df_score: nan
# -----------------------
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-33-49d5b4d08831> in <module>
#       8
#       9     for scoring_metric in scoring_metrics:
# ---> 10         get_span_score = test_evaluator.get_score_spanlist(span_list, scoring_metric)
#      11         score_df = row[scoring_metric + '_score']
#      12         if np.round(get_span_score, 3) != np.round(score_df, 3):
#
# ~/NLP_spark/src/d03_inter_annotator_agreement/inter_annotator_agremment.py in get_score_spanlist(self, span_list, scoring_metric, weight_by_tokens, **optional_tuple_properties)
#     191             total_tokens += n_tokens
#     192
# --> 193         return total_score / total_tokens
#     194
#     195
#
# ZeroDivisionError: division by zero

# %%
rep = repository.from_repository_name('EU_32014R0256_Whereas')
test_evaluator.get_span_list(rep, columns= 'annotators')
# Out:
# [annotator:Fride layer:Policydesigncharacteristics type:Actor tag:Authority_legislative start:46 stop:65 text:european parliament,
#  annotator:Fride layer:Policydesigncharacteristics type:Actor tag:Authority_legislative start:77 stop:84 text:council,
#  annotator:Fride layer:Policydesigncharacteristics type:Actor tag:Authority_default start:144 stop:154 text:commission,
#  annotator:Fride layer:Policydesigncharacteristics type:Reversibility tag:Reversibility_policy start:230 stop:239 text:replacing,
#  annotator:Fride layer:Policydesigncharacteristics type:Reference tag:Ref_PolicyAmended start:240 stop:284 text:council regulation (eu, euratom) no 617/2010,
#  annotator:Fride layer:Policydesigncharacteristics type:Reversibility tag:Reversibility_policy start:289 stop:298 text:repealing,
#  annotator:Fride layer:Policydesigncharacteristics type:Reference tag:Ref_PolicyAmended start:299 stop:332 text:council regulation (ec) no 736/96,
#  annotator:Fride layer:Policydesigncharacteristics type:Actor tag:Authority_legislative start:338 stop:357 text:european parliament,
#  annotator:Fride layer:Policydesigncharacteristics type:Actor tag:Authority_legislative start:366 stop:373 text:council,
#  annotator:Fride layer:Policydesigncharacteristics type:Reference tag:Ref_Strategy_Agreement start:419 stop:466 text:treaty on the functioning of the european union,
#  annotator:Fride layer:Policydesigncharacteristics type:Actor tag:Authority_default start:547 stop:566 text:european commission,
#  annotator:Fride layer:Policydesigncharacteristics type:Actor tag:Authority_default start:683 stop:721 text:european economic and social committee,
#  annotator:Fride layer:Policydesigncharacteristics type:Actor tag:Authority_default start:749 stop:773 text:committee of the regions,
#  annotator:Fride layer:Technologyandapplicationspecificity type:TechnologySpecificity tag:Tech_Other start:181 stop:202 text:energy infrastructure,
#  annotator:Onerva layer:Policydesigncharacteristics type:Actor tag:Authority_legislative start:46 stop:65 text:european parliament,
#  annotator:Onerva layer:Policydesigncharacteristics type:Actor tag:Authority_legislative start:77 stop:84 text:council,
#  annotator:Onerva layer:Policydesigncharacteristics type:Compliance tag:Form_monitoring start:124 stop:136 text:notification,
#  annotator:Onerva layer:Policydesigncharacteristics type:Actor tag:Authority_default start:144 stop:154 text:commission,
#  annotator:Onerva layer:Policydesigncharacteristics type:Reference tag:Ref_PolicyAmended start:240 stop:284 text:council regulation (eu, euratom) no 617/2010,
#  annotator:Onerva layer:Policydesigncharacteristics type:Reference tag:Ref_OtherPolicy start:299 stop:332 text:council regulation (ec) no 736/96,
#  annotator:Onerva layer:Policydesigncharacteristics type:Actor tag:Authority_legislative start:338 stop:357 text:european parliament,
#  annotator:Onerva layer:Policydesigncharacteristics type:Actor tag:Authority_legislative start:366 stop:395 text:council of the european union,
#  annotator:Onerva layer:Policydesigncharacteristics type:Reference tag:Ref_Strategy_Agreement start:419 stop:466 text:treaty on the functioning of the european union,
#  annotator:Onerva layer:Policydesigncharacteristics type:Actor tag:Authority_legislative start:547 stop:566 text:european commission,
#  annotator:Onerva layer:Policydesigncharacteristics type:Actor tag:Authority_legislative start:624 stop:644 text:national parliaments,
#  annotator:Onerva layer:Policydesigncharacteristics type:Actor tag:Authority_default start:683 stop:721 text:european economic and social committee,
#  annotator:Onerva layer:Policydesigncharacteristics type:Actor tag:Authority_default start:749 stop:773 text:committee of the regions]

# %%
treshhold = np.median([(span_.start + span_.stop)/ 2 for span_ in span_list])
spans_overlapping_treshhold = [span_ for span_ in span_list if span_.start < treshhold and span_.stop > treshhold]


i = 1
while len(spans_overlapping_treshhold) != 0:
    treshhold = treshhold + (i * (-1) ** (i-1))
    spans_overlapping_treshhold = [span_ for span_ in span_list if span_.start <= treshhold and span_.stop >= treshhold]
    i +=1


span_list_1 = [span_ for span_ in span_list if span_.stop < treshhold]
span_list_2 = [span_ for span_ in span_list if span_.start > treshhold]

if len(span_list_1) + len(span_list_2) != len(span_list):
    raise ValueError('The splittet spanlist have not the same length as the initial spanlist')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a8b47eb3d238> in <module>
# ----> 1 treshhold = np.median([(span_.start + span_.stop)/ 2 for span_ in span_list])
#       2 spans_overlapping_treshhold = [span_ for span_ in span_list if span_.start < treshhold and span_.stop > treshhold]
#       3
#       4
#       5 i = 1
#
# NameError: name 'span_list' is not defined

# %%
lenght_list =
# Out:
# 913

# %%
test_evaluator.get_score_spanlist(span_list, 'pygamma')
# Out:
# 0.2363175412336929

# %%
(test_evaluator.get_score_spanlist(span_list_1, 'pygamma') * len(span_list_1) + test_evaluator.get_score_spanlist(span_list_2, 'pygamma') * len(span_list_2))/len(span_list)
# Out:
# 0.2363175412336929

# %%
test_evaluator.get_score_spanlist(span_list_2, 'pygamma')
# Out:
# 0.20116640609677472

# %%
#how to get means core
score_cols = [col for col in test_evaluator.df.columns if 'score' in col]
for col in score_cols:
    print(col, ' : ', test_evaluator.df[col].mean(skipna = True))
# Out:
# f1_exact_score  :  0.4072354313660465
# f1_tokenwise_score  :  0.4037227690416303
# f1_partial_score  :  0.5235818906050609
# f1_heuristic_score  :  0.5350255029370727

# %%
#test weighting score by tokens
test_evaluator.get_total_score_df()
# Out:
# {'f1_exact_score': 0.24962194821446082,
#  'f1_tokenwise_score': 0.2338647858734802,
#  'f1_partial_score': 0.3145298761379569,
#  'f1_heuristic_score': 0.3231179223979568}

# %%
test_dir = repository.from_repository_name('EU_32018L2001')
span_list = test_evaluator.get_span_list(test_dir, columns='annotators')
test_evaluator.get_score_spanlist(span_list, 'f1_heuristic')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-c0fa2f501abc> in <module>
# ----> 1 test_dir = repository.from_repository_name('EU_32018L2001')
#       2 span_list = test_evaluator.get_span_list(test_dir, columns='annotators')
#       3 test_evaluator.get_score_spanlist(span_list, 'f1_heuristic')
#       4
#
# ~/NLP_spark/src/experiment_utils/helper_classes.py in from_repository_name(cls, rep_str)
#      27         folder_parts = rep_str.split('_')                  #split the string at '_' into parts
#      28         policy = folder_parts[0] + '_' + folder_parts[1]   #we only want to split at every 2nd '_', so merge the 1. and 2., 3. and 4. again
# ---> 29         if folder_parts[2] in  ['front', 'Whereas']:       #exeption for the 'whereas' and 'front'
#      30             title = folder_parts[2]
#      31             chapter = None
#
# IndexError: list index out of range

# %%
#test all articles
for index, row in df.iterrows():
    repo = repository.from_repository_name(row.index)

# %%
#should be the same as above
score_cols = [col for col in test_evaluator.df.columns if 'score' in col]
for score_col in score_cols:
    sum_ = 0
    total_tokens = 0
    count = 0
    for i, row in test_evaluator.df.iterrows():
        sum_ = np.sum(sum_, len(row['Tokens']) * row[score_col])
        if row[score_col] != np.nan:
            total_tokens += len(row['Tokens'])
            count +=1
    print(score_col, sum_/total_tokens)
    print(count)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-16c1ff101e2f> in <module>
#       6     count = 0
#       7     for i, row in test_evaluator.df.iterrows():
# ----> 8         sum_ = np.sum(sum_, len(row['Tokens']) * row[score_col])
#       9         if row[score_col] != np.nan:
#      10             total_tokens += len(row['Tokens'])
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# ~/miniconda3/envs/nlp_spark/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2246
#    2247     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2248                           initial=initial, where=where)
#    2249
#    2250
#
# ~/miniconda3/envs/nlp_spark/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# ## Testing get_score_spanlist

# %%
#itnitialize test evaluator again, this time with debug 
test_evaluator_debug = Inter_Annotator_Agreement(stat_df, DEBUG = True)
scoring_metrics = ['f1_exact', 'f1_tokenwise', 'f1_partial', 'f1_heuristic']

test_evaluator_debug.append_total_score_per_article_no_parallel(scoring_metrics, append_to_df = True, weight_by_tokens = True)

# %%
test_evaluator_debug.df
# Out:
#                                                    Policy  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...
# EU_32013R0525_Title_0_Chapter_7_Section_0_Artic...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...
# EU_32009R0079_Title_0_Chapter_0_Section_0_Artic...
# EU_32006L0032_Title_0_Chapter_4_Section_0_Artic...
#
#                                                                                                  Text  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  article 43\r\nexercise of the delegation\r\n1....
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  article 12\r\nreal-world co2 emissions and fue...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  article 11\r\njoint projects between member st...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  article 56\r\namendments to directive (eu) 201...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  article 3\r\nbinding overall union target for ...
# EU_32013R0525_Title_0_Chapter_7_Section_0_Artic...  article 23\r\ncooperation between the member s...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...  article 30\r\naddressees\r\nthis directive is ...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...  article 21\r\nspecific provisions related to e...
# EU_32009R0079_Title_0_Chapter_0_Section_0_Artic...  article 1\r\nsubject matter\r\nthis regulation...
# EU_32006L0032_Title_0_Chapter_4_Section_0_Artic...  article 16\r\ncommittee\r\n1.   the commission...
#
#                                                                                                Tokens  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32013R0525_Title_0_Chapter_7_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32009R0079_Title_0_Chapter_0_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
# EU_32006L0032_Title_0_Chapter_4_Section_0_Artic...  [start:0 stop:7 text:article tag_count:0, star...
#
#                                                                                              Curation  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  [annotator:curation layer:Instrumenttypes type...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [annotator:curation layer:Instrumenttypes type...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [annotator:curation layer:Instrumenttypes type...
# EU_32013R0525_Title_0_Chapter_7_Section_0_Artic...  [annotator:curation layer:Instrumenttypes type...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...  [annotator:curation layer:Policydesigncharacte...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...  [annotator:curation layer:Instrumenttypes type...
# EU_32009R0079_Title_0_Chapter_0_Section_0_Artic...  [annotator:curation layer:Instrumenttypes type...
# EU_32006L0032_Title_0_Chapter_4_Section_0_Artic...
#
#                                                                                                Alisha  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  [annotator:Alisha layer:Instrumenttypes type:I...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  [annotator:Alisha layer:Policydesigncharacteri...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...
# EU_32013R0525_Title_0_Chapter_7_Section_0_Artic...  [annotator:Alisha layer:Instrumenttypes type:I...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...  [annotator:Alisha layer:Instrumenttypes type:I...
# EU_32009R0079_Title_0_Chapter_0_Section_0_Artic...                                                 []
# EU_32006L0032_Title_0_Chapter_4_Section_0_Artic...
#
#                                                                                                 Fride  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  [annotator:Fride layer:Policydesigncharacteris...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [annotator:Fride layer:Instrumenttypes type:In...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...  [annotator:Fride layer:Policydesigncharacteris...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [annotator:Fride layer:Instrumenttypes type:In...
# EU_32013R0525_Title_0_Chapter_7_Section_0_Artic...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...  [annotator:Fride layer:Policydesigncharacteris...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...
# EU_32009R0079_Title_0_Chapter_0_Section_0_Artic...
# EU_32006L0032_Title_0_Chapter_4_Section_0_Artic...  [annotator:Fride layer:Instrumenttypes type:In...
#
#                                                                                                Onerva  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic...  [annotator:Onerva layer:Instrumenttypes type:I...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [annotator:Onerva layer:Instrumenttypes type:I...
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32018L2001_Title_0_Chapter_0_Section_0_Artic...  [annotator:Onerva layer:Instrumenttypes type:I...
# EU_32013R0525_Title_0_Chapter_7_Section_0_Artic...
# EU_32006L0066_Title_0_Chapter_0_Section_0_Artic...  [annotator:Onerva layer:Policydesigncharacteri...
# EU_32009L0028_Title_0_Chapter_0_Section_0_Artic...                                                 []
# EU_32009R0079_Title_0_Chapter_0_Section_0_Artic...  [annotator:Onerva layer:Instrumenttypes type:I...
# EU_32006L0032_Title_0_Chapter_4_Section_0_Artic...  [annotator:Onerva layer:Instrumenttypes type:I...
#
#                                                                                                Fabian  \
# EU_32018R1999_Title_0_Chapter_7_Section_3_Artic...
# EU_32019R0631_Title_0_Chapter_0_Section_0_Artic
# EU_32009R0079_Title_0_Chapter_0_Section_0_Artic...            0.545455
# EU_32006L0032_Title_0_Chapter_4_Section_0_Artic...            0.625000

# %%
test_dir = repository()

# %%
#get all tags of fabian and curation
span_list_Fabian = test_evaluator_debug.get_span_list(test_dir, ['Curation', 'Fabian'])

# %%
#get all tags of Fride and curation
span_list_fride = test_evaluator_debug.get_span_list(test_dir, ['Curation', 'Fride'])

# %%
#inter annotator agreement to curation
test_evaluator_debug.get_score_spanlist(span_list_fride, 'pygamma', 'f1_partial', weight_by_tokens = True)
# Out:
# 0.8329641657864452

# %%
#should be the same as above
Fride_df = test_evaluator_debug.df[test_evaluator.df.apply(lambda x : len(x['Fride']) >=2 and len(x['Curation']) >=2,axis=1)]
scoring_metric = 'f1_partial'
score = 0
total_tokens = 0

for i, row in Fride_df.iterrows():
    span_list = list(chain.from_iterable(row[['Fride', 'Curation']]))
    score_article = _get_score_article(span_list, 'pygamma', scoring_metric)
    score += score_article * len(row['Tokens'])
    total_tokens += len(row['Tokens'])
print(score/total_tokens)
# Out:
# 0.8329641657864452

# %%
#inter annotator agreement to curation
test_evaluator_debug.get_score_spanlist(span_list_Fabian, 'pygamma', 'f1_partial', weight_by_tokens = True)
# Out:
# 0.5043968618187368

# %%
Fabian_df = test_evaluator_debug.df[test_evaluator.df.apply(lambda x : len(x['Fabian']) >=2 and len(x['Curation']) >=2,axis=1)]
scoring_metric = 'f1_partial'
score = 0
total_tokens = 0

for i, row in Fabian_df.iterrows():
    span_list = list(chain.from_iterable(row[['Fabian', 'Curation']]))
    score_article = _get_score_article(span_list, 'pygamma', scoring_metric)
    score += score_article * len(row['Tokens'])
    total_tokens += len(row['Tokens'])
print(score/total_tokens)
# Out:
# 0.5043968618187368

# %%
#should be the same as above
score_cols = [col for col in test_evaluator_debug.df.columns if 'score' in col]
for score_col in score_cols:
    sum_ = 0
    total_tokens = 0
    count = 0
    for i, row in test_evaluator_debug.df.iterrows():
        sum_ += len(row['Tokens']) * row[score_col]
        total_tokens += len(row['Tokens'])
        count +=1
    print(score_col, sum_/total_tokens)
# Out:
# f1_exact_score 0.4339525189955403
# f1_tokenwise_score 0.4020799601240799
# f1_partial_score 0.5246164949054787
# f1_heuristic_score 0.5287564930463238

# %%
test_evaluator_debug.get_total_score_df()
# Out:
# {'f1_exact_score': 0.4339525189955403,
#  'f1_tokenwise_score': 0.40207996012408,
#  'f1_partial_score': 0.5246164949054787,
#  'f1_heuristic_score': 0.5287564930463238}

# %%
scoring_metrics = ['f1_exact', 'f1_tokenwise', 'f1_partial', 'f1_heuristic']
for scoring_metric in scoring_metrics:
    print(test_evaluator.df[scoring_metric + '_score'].isna().sum())
# Out:
# 20
# 20
# 20
# 20

# %%
test_dir = repository()
span_list = test_evaluator_debug.get_span_list(test_dir, columns = 'annotators')
test_evaluator_debug.get_score_spanlist(span_list, 'f1_heuristic')
# Out:
# 0.5287564930463238

# %%
test_dir= repository.from_repository_name('EU_32018R1999_Title_0_Chapter_7_Section_3_Article_56')
span_list =

# %%
#test all articles
scoring_metrics = ['f1_exact', 'f1_tokenwise', 'f1_partial', 'f1_heuristic']

for index, row in test_evaluator_debug.df.iterrows():
    repo = repository.from_repository_name(index)
    span_list = test_evaluator_debug.get_span_list(repo, columns = 'annotators')

    for scoring_metric in scoring_metrics:
        get_span_score = test_evaluator_debug.get_score_spanlist(span_list, scoring_metric)
        score_df = row[scoring_metric + '_score']
        if np.round(get_span_score, 3) != np.round(score_df, 3):
            print(index)
            print('span_score:', get_span_score)
            print('df_score:' , score_df)

# %% [markdown]
# ## Test get_score_anotator

# %%
test_evaluator_debug.get_score_annotator('Fride')
# Out:
# {'pygamma_matching_f1_exact_score': 0.3234483607575073,
#  'pygamma_matching_f1_tokenwise_score': 0.3592157908127133,
#  'pygamma_matching_f1_partial_score': 0.4798720598959412}

# %%
annotator_df = test_evaluator_debug.df[test_evaluator.df.apply(lambda x : len(x['Fride']) >=2,axis=1)]

# %%
#should be the same as this one
sum = 0
for i, row in annotator_df.iterrows():
    sum += len(row['Tokens']) * row['pygamma_matching_f1_partial_score']
sum/len(list(chain.from_iterable(annotator_df['Tokens'])))
# Out:
# 0.47987205989594117

# %%
sum = 0
for i, row in annotator_df.iterrows():
    sum += len(row['Tokens']) * row['pygamma_matching_f1_tokenwise_score']
sum/len(list(chain.from_iterable(annotator_df['Tokens'])))
# Out:
# 0.35921579081271326

# %% [markdown]
# ## Test heuristic_f1

# %%
test_dir = test_evaluator_debug.df['Curation'][2][1].rep
span_list = test_evaluator_debug.get_span_list(test_dir, ['Fabian', 'Alisha'])
from src.d03_inter_annotator_agreement.scoring_functions import f1_heuristic

# %%
f1_heuristic(span_list, ( 'Alisha', 'Fabian'))
# Out:
# 0.425531914893617

# %%
test_dir = repository.from_repository_name('EU_32006L0032_Title_0_Chapter_1_Section_0_Article_03')
span_list = test_evaluator_debug.get_span_list(test_dir, ['Onerva', 'Fride'])

# %%
f1_heuristic(span_list, ('Fride', 'Onerva'))
# Out:
# 0.5664166174246597

# %%
test_dir = repository.from_repository_name('EU_32019R0631_Title_0_Chapter_0_Section_0_Article_16')

# %%
test_evaluator_debug.get_score_spanlist(span_list, 'f1_heuristic')
# Out:
# 0.2628571428571429

# %%
import json

from definitions import ROOT_DIR


data_path = os.path.join(ROOT_DIR,'data')

project_log = 'annotator_data/exportedproject540378092697116778.json'



article_state = {'articles': []}
with open(os.path.join(data_path, project_log)) as json_file:
    article_state_data = json.load(json_file)
    for article in article_state_data['source_documents']:

        policy_name = article['name']
        policy_state = article['state']
        finished_coders = [doc_article['user'] for doc_article in article_state_data['annotation_documents'] if doc_article['name'] == policy_name and doc_article['state'] == 'FINISHED']

        this_state = {'name': article['name'],
                       'finished_coders': finished_coders}
        article_state['articles'].append(this_state)

# %%
import json

from definitions import ROOT_DIR


data_path = os.path.join(ROOT_DIR,'data')

project_log = 'annotator_data/exportedproject540378092697116778.json'



article_state = {}
with open(os.path.join(data_path, project_log)) as json_file:
    article_state_data = json.load(json_file)
    for article in article_state_data['source_documents']:

        policy_name = article['name']
        policy_state = article['state']
        finished_coders = [doc_article['user'] for doc_article in article_state_data['annotation_documents'] if doc_article['name'] == policy_name and doc_article['state'] == 'FINISHED']

        this_state = {'state': article['state'],
                       'finished_coders': finished_coders}
        article_state[policy_name] = this_state

# %%
article_state['EU_32012L0027_Title_0_Chapter_2_Section_0_Article_05.txt']
# Out:
# {'state': 'CURATION_FINISHED', 'finished_coders': ['Fride', 'Onerva']}

# %%
[article['user'] for article in data['annotation_documents'] if article['name'] == 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_01.txt' and article['state'] == 'FINISHED']
# Out:
# ['Fride', 'Onerva']

# %%
for article in data['annotation_documents']:
    print(article)
# Out:
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_01.txt', 'user': 'Lynn', 'state': 'IN_PROGRESS', 'timestamp': 1602953239000, 'sentence_accessed': 0, 'created': None, 'updated': 1602953239000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_01.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605365160000, 'sentence_accessed': 0, 'created': None, 'updated': 1605634715000}
# {'name': 'EU_32006L0066_front.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605364856000, 'sentence_accessed': 0, 'created': None, 'updated': 1605634693000}
# {'name': 'EU_32006L0066_Whereas.txt', 'user': 'Fride', 'state': 'IN_PROGRESS', 'timestamp': None, 'sentence_accessed': 0, 'created': None, 'updated': 1602999231000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_02.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605365267000, 'sentence_accessed': 0, 'created': None, 'updated': 1605634814000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_03.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605634894000, 'sentence_accessed': 0, 'created': None, 'updated': 1605634928000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_04.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605366089000, 'sentence_accessed': 0, 'created': None, 'updated': 1605634944000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_05.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605366290000, 'sentence_accessed': 0, 'created': None, 'updated': 1605634958000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_06.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605366457000, 'sentence_accessed': 0, 'created': None, 'updated': 1605634975000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_07.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605366546000, 'sentence_accessed': 0, 'created': None, 'updated': 1605634994000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_08.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605635042000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635050000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_09.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605366872000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635530000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_10.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605366989000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635547000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_11.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605367094000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635564000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_12.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605367278000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635731000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_13.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605367416000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635748000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_14.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605635769000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635773000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_15.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605423288000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635788000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_16.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605635827000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635831000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_17.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1603263356000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635871000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_18.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605423550000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635856000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_19.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605423692000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635893000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_20.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605423841000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635910000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_21.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605635938000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635948000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_22.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605635972000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635977000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_23.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605424281000, 'sentence_accessed': 0, 'created': None, 'updated': 1605635995000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_24.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605424350000, 'sentence_accessed': 0, 'created': None, 'updated': 1605636010000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_25.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605424403000, 'sentence_accessed': 0, 'created': None, 'updated': 1605636029000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article_26.txt', 'user': 'Fride', 'state': 'FINISHED', 'timestamp': 1605424455000, 'sentence_accessed': 0, 'created': None, 'updated': 1605636052000}
# {'name': 'EU_32006L0066_Title_0_Chapter_0_Section_0_Article